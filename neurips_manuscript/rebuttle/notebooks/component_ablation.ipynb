# %% [markdown]
# ## Status (created 2026-07-30) -- READ BEFORE RUNNING
#
# **Standalone ComBat baseline notebook.** Deliberately a SEPARATE notebook from
# `batch_correct_then_cluster_baselines.ipynb` (not an added arm inside it) so the two can
# be run in parallel Colab sessions without one's config/state stomping the other's --
# same underlying helper module (`interpretable_ssl/evaluation/batch_correct_baselines.py`),
# just a different `CORRECTION_METHODS` value (`['combat']` here vs. `['harmony']` there).
#
# Results land in the exact same on-disk run folders/metrics.json format the other
# notebook uses (`seacell_X_combat`, `leiden_X_combat_K{n}`), so the comparison tables
# below can pull in Harmony/scPoli/scVI results too, if those have already been run --
# no need to re-run anything from the other notebook to see them side by side here.
#
# If you already have this notebook open in another Colab tab, close it (or File >
# Revert) first -- Colab autosaving from a stale tab can silently overwrite this file.

# %% [markdown]
# # Rebuttal experiment: ComBat batch-correction-then-cluster baseline -- ComBat latent -> {SEACells, Leiden}
#
# **Purpose.** Reviewer nG29 (Question 3): *"How would batch-correction preprocessing
# affect the comparison to other baselines? It would be interesting to see how the
# performance of scProto would compare to other baselines if batch effects were removed a
# priori (for example with Harmony or ComBat)."* The Harmony half of this question is
# already answered in `batch_correct_then_cluster_baselines.ipynb`. This notebook runs the
# ComBat half: apply original ComBat (Johnson, Li & Rabinovic 2007 -- `scanpy.pp.combat`,
# built into scanpy, no extra install) to each dataset's log-normalized expression, PCA the
# corrected matrix, then run **both** SEACells and Leiden on the resulting embedding --
# replacing the paper's original weak `scPoli + K-means`-only comparison with a proper
# two-step baseline, exactly as requested.
#
# **Why ComBat is a meaningfully different comparison than Harmony/scPoli/scVI:** those
# three all correct via a learned or iteratively-clustered embedding. ComBat instead fits
# one linear (shift, spread) correction per gene per batch directly on gene expression --
# no embedding, no clustering step, no neural network. Two structural properties of that
# correction are worth watching for in the results (see
# `baseline-notes/combat-notes.md` for the full reasoning):
#
# 1. ComBat cannot distinguish a genuine batch artifact from a rare cell state that
#    happens to be confined to one batch -- both look like "batch i has an unusual mean
#    for this gene," and correcting one flattens the other too.
# 2. ComBat fits a SINGLE shift per gene per batch, applied uniformly to every cell in
#    that batch, even though real batch effects are well documented to hit different cell
#    types/states by different amounts.
#
# Both point at the same place: the rare-cell coverage/homogeneity/F1 table below is the
# sharpest test of whether either limitation actually shows up in these three datasets --
# watch that table first, not just the headline modularity/purity numbers.

# %% [markdown]
# ## Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q scarches faiss-gpu-cu12 scib-metrics
# !pip install git+https://github.com/dpeerlab/SEACells.git --quiet --no-deps
# !pip install numpy scipy --upgrade -q
# !pip install -q palantir harmonypy
# !pip install -q "numpy==1.26.4" "scipy==1.13.1"
# !pip install --upgrade --force-reinstall numpy cupy-cuda12x
# !pip install "numpy<2.3"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 MB 65.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.5/187.5 kB 30.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 216.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 189.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 215.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 221.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 134.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 711.2/711.2 kB 86.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.3/102.3 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 162.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.7/295.7 kB 38.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 17.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.6/848.6 kB 87.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 55.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.9/155.9 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 84.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.6/319.6 kB 36.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 79.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 230.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.0/183.0 kB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 72.8 MB/s eta 0:00:00
#   Building wheel for docrep (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.5 which is incompatible.
# pytensor 2.38.3 requires numba<=0.65.1,>=0.58, but you have numba 0.66.0 which is incompatible.
# ibis-framework 9.5.0 requires toolz<1,>=0.11, but you have toolz 1.1.0 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.66.0 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.66.0 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.
#   Preparing metadata (setup.py) ... done
#   Building wheel for SEACells (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 239.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 105.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# seacells 0.3.3 requires palantir, which is not installed.
# seacells 0.3.3 requires pyranges, which is not installed.
# numba 0.66.0 requires numpy<2.5,>=1.22, but you have numpy 2.5.1 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.5 which is incompatible.
# pytensor 2.38.3 requires numba<=0.65.1,>=0.58, but you have numba 0.66.0 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.66.0 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.66.0 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.5/64.5 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 74.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.4/172.4 kB 25.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# seacells 0.3.3 requires pyranges, which is not installed.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.5 which is incompatible.
# pytensor 2.38.3 requires numba<=0.65.1,>=0.58, but you have numba 0.66.0 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.66.0 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.66.0 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 189.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 95.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# seacells 0.3.3 requires pyranges, which is not installed.
# faiss-gpu-cu12 1.14.1.post1 requires numpy<3,>=2, but you have numpy 1.26.4 which is incompatible.
# fast-array-utils 1.5 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# scanpy 1.12.3 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# anndata 0.13.2 requires numpy>=2.1, but you have numpy 1.26.4 which is incompatible.
# anndata 0.13.2 requires scipy!=1.17.0,>=1.14, but you have scipy 1.13.1 which is incompatible.
# zarr 3.2.1 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.5 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numba<=0.65.1,>=0.58, but you have numba 0.66.0 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.2 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# access 1.1.10.post3 requires scipy>=1.14.1, but you have scipy 1.13.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.66.0 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.52.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.66.0 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Collecting numpy
#   Using cached numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting cupy-cuda12x
#   Downloading cupy_cuda12x-14.1.1-cp312-cp312-manylinux2014_x86_64.whl.metadata (2.8 kB)
# Collecting cuda-pathfinder==1.*,>=1.3.4 (from cupy-cuda12x)
#   Downloading cuda_pathfinder-1.6.0-py3-none-any.whl.metadata (1.9 kB)
# Using cached numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.7 MB)
# Downloading cupy_cuda12x-14.1.1-cp312-cp312-manylinux2014_x86_64.whl (133.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 MB 18.9 MB/s eta 0:00:00
# Downloading cuda_pathfinder-1.6.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 8.0 MB/s eta 0:00:00
# Installing collected packages: numpy, cuda-pathfinder, cupy-cuda12x
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: cuda-pathfinder
#     Found existing installation: cuda-pathfinder 1.5.6
#     Uninstalling cuda-pathfinder-1.5.6:
#       Successfully uninstalled cuda-pathfinder-1.5.6
#   Attempting uninstall: cupy-cuda12x
#     Found existing installation: cupy-cuda12x 14.0.1
#     Uninstalling cupy-cuda12x-14.0.1:
#       Successfully uninstalled cupy-cuda12x-14.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# seacells 0.3.3 requires pyranges, which is not installed.
# scipy 1.13.1 requires numpy<2.3,>=1.22.4, but you have numpy 2.5.1 which is incompatible.
# numba 0.66.0 requires numpy<2.5,>=1.22, but you have numpy 2.5.1 which is incompatible.
# anndata 0.13.2 requires scipy!=1.17.0,>=1.14, but you have scipy 1.13.1 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.5 which is incompatible.
# pytensor 2.38.3 requires numba<=0.65.1,>=0.58, but you have numba 0.66.0 which is incompatible.
# tsfresh 0.21.2 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# access 1.1.10.post3 requires scipy>=1.14.1, but you have scipy 1.13.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.66.0 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.66.0 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.
# Successfully installed cuda-pathfinder-1.6.0 cupy-cuda12x-14.1.1 numpy-2.5.1
# Collecting numpy<2.3
#   Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.5 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 217.6 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.5.1
#     Uninstalling numpy-2.5.1:
#       Successfully uninstalled numpy-2.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# seacells 0.3.3 requires pyranges, which is not installed.
# anndata 0.13.2 requires scipy!=1.17.0,>=1.14, but you have scipy 1.13.1 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.5 which is incompatible.
# pytensor 2.38.3 requires numba<=0.65.1,>=0.58, but you have numba 0.66.0 which is incompatible.
# tsfresh 0.21.2 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# access 1.1.10.post3 requires scipy>=1.14.1, but you have scipy 1.13.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.66.0 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.66.0 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.
# Successfully installed numpy-2.2.6

# %%
# IMPORTANT: restart the runtime after this cell before running the cells below --
# numpy/scipy/anndata are C-extension linked, an in-process upgrade alone won't
# reliably take effect on already-imported modules.
#
# Note: scarches/scvi-tools/harmonypy are installed above even though THIS notebook
# only runs ComBat (which is plain scanpy, sc.pp.combat, no extra package) --
# run_all_baselines_for_dataset always calls get_stage1_latent() first to build `ad`
# from the existing scPoli Stage-1 checkpoint, and that path needs scarches/scvi
# importable regardless of which correction method is requested afterward.

# %%
# Ground truth for "did the install cell above actually work" -- pip's own log is
# noisy (resolver backtracking prints "Getting requirements to build wheel" errors
# for discarded candidate versions even on a fully successful install), so eyeballing
# it is unreliable. Actually importing every package we just installed is the real
# test.
_checks = {
    'numpy': 'numpy', 'scipy': 'scipy', 'anndata': 'anndata', 'scanpy': 'scanpy',
    'scarches': 'scarches', 'scvi-tools': 'scvi', 'seacells': 'SEACells',
    'palantir': 'palantir', 'scib-metrics': 'scib_metrics', 'leidenalg': 'leidenalg',
    'python-igraph': 'igraph', 'umap-learn': 'umap', 'harmonypy': 'harmonypy',
    'faiss-cpu': 'faiss',
}
_failed = []
for pkg_name, import_name in _checks.items():
    try:
        mod = __import__(import_name)
        ver = getattr(mod, '__version__', '?')
        print(f"  OK   {pkg_name:16s} (import {import_name}, version {ver})")
    except Exception as e:
        _failed.append(pkg_name)
        print(f"  FAIL {pkg_name:16s} (import {import_name}): {type(e).__name__}: {e}")

if _failed:
    print(f"\n{len(_failed)} package(s) failed to import: {_failed} -- re-run that "
          f"package's specific pip install line above and check its full error "
          f"output before proceeding.")
else:
    print(f"\nAll {len(_checks)} packages import cleanly -- safe to continue.")
# Out:
#   OK   numpy            (import numpy, version 2.2.6)
#   OK   scipy            (import scipy, version 1.13.1)
# /tmp/ipykernel_2525/3189155525.py:17: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('anndata')` instead.
#   ver = getattr(mod, '__version__', '?')
# /tmp/ipykernel_2525/3189155525.py:17: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   ver = getattr(mod, '__version__', '?')
#   OK   anndata          (import anndata, version 0.13.2)
#   OK   scanpy           (import scanpy, version 1.12.3)
# WARNING:root:In order to use the mouse gastrulation seqFISH datsets, please install squidpy (see https://github.com/scverse/squidpy).
#   FAIL scarches         (import scarches): ImportError: cannot import name 'read' from 'anndata' (/usr/local/lib/python3.12/dist-packages/anndata/__init__.py)
#   OK   scvi-tools       (import scvi, version 1.5.0.post1)
#   OK   seacells         (import SEACells, version 0.3.3)
#   OK   palantir         (import palantir, version 1.4.5)
#   OK   scib-metrics     (import scib_metrics, version 0.6.0)
#   OK   leidenalg        (import leidenalg, version 0.12.0)
#   OK   python-igraph    (import igraph, version 1.0.0)
#   OK   umap-learn       (import umap, version 0.5.12)
#   OK   harmonypy        (import harmonypy, version 2.0.0)
#   OK   faiss-cpu        (import faiss, version 1.14.1)
#
# 1 package(s) failed to import: ['scarches'] -- re-run that package's specific pip install line above and check its full error output before proceeding.

# %%
# %run /content/drive/MyDrive/codes/interpretable-prototype/notebooks/nb_setup.py
# Out:
# nb_setup done. Available: get_trainer, run_mc_task, fig_*, LAMBDA_PROTO_UMAP, LAMBDA_PROTO_UMAP_PRECON, LAMBDA_PARAM_UMAP, LAMBDA_RECON_ONLY, train_sure, eval_sure_task1/2/3
# Configs: {'LAMBDA_PROTO_UMAP': {'lambda_umap': 1, 'lambda_swav': 0, 'lambda_kl': 0, 'lambda_recon': 0, 'lambda_proto_recon': 0.0, 'umap_similarity': 'proto'}, 'LAMBDA_PARAM_UMAP': {'lambda_umap': 1, 'lambda_swav': 0, 'lambda_kl': 0, 'lambda_recon': 0, 'lambda_proto_recon': 0.0, 'umap_similarity': 'embedding'}, 'LAMBDA_RECON_ONLY': {'lambda_umap': 0, 'lambda_swav': 0, 'lambda_kl': 0, 'lambda_recon': 1, 'lambda_proto_recon': 0.0}}

# %%
# Extra imports not already covered by nb_setup.py (which already pulls in
# run_mc_task, eval_seacell_task1/2/3, load_task1_multi, show_table, clean_run_names,
# rare_celltype_purity_table, TASK1_METRICS, TASK2_METRICS, extract_model_key via
# `from interpretable_ssl.evaluation.paper_figures import *` and
# `from interpretable_ssl.evaluation.metric_helpers.result_tables import *`).
from interpretable_ssl.datasets.dataset_configs import DATASETS
from interpretable_ssl.configs.paths import get_dataset_model_dir

print("extra imports ready")
# Out:
# extra imports ready

# %% [markdown]
# ## Config
#
# Same hyperparameters `train_scproto.ipynb` used to produce the existing Stage-1
# checkpoints for these three datasets (`cvae_epochs=50`, `batch_size=1024`) -- must
# match, or `load_pretrain_checkpoint()` looks in the wrong folder. `K` (n_SEACells /
# target Leiden cluster count) defaults to each dataset's `num_prototypes` from
# `DATASETS`, matching `results.tex`: *"All baselines are configured to produce the same
# number of metacells K as scProto."*

# %%
RNA_SEQ_DATASETS = ['pancreas', 'lung', 'pbmc-immune']

SKIP_IF_EXISTS = True  # skip a baseline entirely (embedding + SEACells + Leiden) if its
                        # metrics.json already exists on disk -- re-running the dataset
                        # cell after a crash/interrupt never redoes already-saved work.

CORRECTION_METHODS = ['combat']  # this notebook: ComBat only (see intro cell)
METHOD_DISPLAY_NAMES = {
    'combat': 'ComBat',
}

RUN_SEACELLS = True  # both SEACells AND Leiden on top of ComBat -- reviewer nG29's Q3
                      # asked for the comparison itself, not one clusterer in isolation.
RUN_LEIDEN = True

# %% [markdown]
# ## Helper functions
#
# Shared with the Harmony notebook -- lives in
# `interpretable_ssl/evaluation/batch_correct_baselines.py` (imported below), not
# redefined here. ComBat support (`get_combat_corrected_pca`, and the `'combat'` branch
# in `run_correction_method`) was added to that same module, so no separate helper file
# exists for this notebook -- fixing a bug in the shared pipeline benefits both notebooks
# at once, avoiding the exact duplication risk the Harmony notebook's own intro cell
# describes from when it used to be split in two.

# %%
from interpretable_ssl.evaluation.batch_correct_baselines import run_all_baselines_for_dataset

print("baseline helper functions ready (interpretable_ssl.evaluation.batch_correct_baselines)")
# Out:
# baseline helper functions ready (interpretable_ssl.evaluation.batch_correct_baselines)

# %% [markdown]
# ## Run: Pancreas

# %%
pancreas_results = run_all_baselines_for_dataset(
    'pancreas', correction_methods=CORRECTION_METHODS, skip_if_exists=SKIP_IF_EXISTS,
    run_seacells=RUN_SEACELLS, run_leiden=RUN_LEIDEN,
)
# Out:
# WARNING:root:In order to use sagenet models, please install pytorch geometric (see https://pytorch-geometric.readthedocs.io) and
#  captum (see https://github.com/pytorch/captum).
# WARNING:root:mvTCR is not installed. To use mvTCR models, please install it first using "pip install mvtcr"
# WARNING:root:multigrate is not installed. To use multigrate models, please install it first using "pip install multigrate".
# dataset is None, loading pancreas
# loading pancreas data
# ✅ Already subsetted to HVGs (4000 genes).
# stage1_latent_extract_ds-panc_NP220_aff-arbf_cvae_e50_v31
# Embedding dictionary:
#  	Num conditions: [9]
#  	Embedding dim: [10]
# Encoder Architecture:
# 	Input Layer in, out and cond: 4000 64 10
# 	Mean/Var Layer in/out: 64 8
# Decoder Architecture:
# 	First Layer in, out and cond:  8 64 10
# 	Output Layer in/out:  64 4000
#
# 📊 Affinity: wdeg[min/mean/max]=5.446/23.916/92.201, effk_med=62.4, mutual=100.00%
# adam
# Loaded pretrain checkpoint from /content/drive/MyDrive/models/pancreas/pretrain/pretrain_ds-pancreas_cvae_e50/pretrain_checkpoint.pth
#   pretrain_params: {'dataset_id': 'pancreas', 'cvae_epochs': 50, 'batch_size': 1024, 'latent_dims': 8, 'l2norm': 1, 'model_type': 'gm', 'beta': 0.3, 'condition_key': 'tech'}
#   0%|          | 0/16 [00:00<?, ?it/s]
# [pancreas] Stage-1 latent: 16382 cells x 8 dims
# dataset is None, loading pancreas
# loading pancreas data
# ✅ Already subsetted to HVGs (4000 genes).
# proto_umap_ds-panc_NP220_prtInit-wayp_aff-arbf_lprec0.01_usim-prot_cvae_e50_ecal1_lpu0.1_pum-ema_lna1_nagg-max_upm-dotp_v31
# Embedding dictionary:
#  	Num conditions: [9]
#  	Embedding dim: [10]
# Encoder Architecture:
# 	Input Layer in, out and cond: 4000 64 10
# 	Mean/Var Layer in/out: 64 8
# Decoder Architecture:
# 	First Layer in, out and cond:  8 64 10
# 	Output Layer in/out:  64 4000
#
# 📊 Affinity: wdeg[min/mean/max]=5.446/23.916/92.201, effk_med=62.4, mutual=100.00%
# adam
# Loaded pretrain checkpoint from /content/drive/MyDrive/models/pancreas/pretrain/pretrain_ds-pancreas_cvae_e50/pretrain_checkpoint.pth
#   pretrain_params: {'dataset_id': 'pancreas', 'cvae_epochs': 50, 'batch_size': 1024, 'latent_dims': 8, 'l2norm': 1, 'model_type': 'gm', 'beta': 0.3, 'condition_key': 'tech'}
# 📊 EdgeDataset: 1155146 edges
#    Weight range: [0.0320, 0.9688]
#    umap_steps_per_epoch=500 → 512000 edges/epoch (of 1155146 total)
# 📐 UMAP kernel: min_dist=0.5, spread=1.0 -> a=0.5830, b=1.3342
# Starting edge-centric UMAP training (similarity=proto)
#    min_dist=0.5, spread=1.0, neg_rate=5
#    lambda_umap=1, lambda_recon=0, lambda_kl=0, lambda_proto_recon=0.01, lambda_r1r2=0.0
#    nassoc: λ=1, agg=max, diag=ON [(m-1)²], offdiag=[m²]
# Loaded UMAP checkpoint from /content/drive/MyDrive/models//pancreas/proto_umap_ds-panc_NP220_prtInit-wayp_aff-arbf_lprec0.01_usim-prot_cvae_e50_ecal1_lpu0.1_pum-ema_lna1_nagg-max_upm-dotp_v31/umap_checkpoint.pth (epoch 3)
#   0%|          | 0/16 [00:00<?, ?it/s]
# === [pancreas] batch-correction method: combat ===
# [pancreas] combat: cached embedding to /content/drive/MyDrive/models/pancreas/_cache_X_combat_emb.npy
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/16382 [00:00<?, ?it/s]
# Making graph symmetric...
# Parameter graph_construction = union being used to build KNN graph...
# Computing RBF kernel...
#   0%|          | 0/16382 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/16382 [00:00<?, ?it/s]
# Constructing CSR matrix...
# [waypoint init] N=16382  k=220  n_eigs=10  nnz=1249050  nnz/row=76.2
# [waypoint init] computing diffusion map ...
# [waypoint init] diffusion map done — 10 eigenvectors
# waypoint MaxMin: 100%|██████████| 219/219 [00:00<00:00, 9735.90archetype/s]
# [waypoint init] selected 220 archetype seed cells
# [SEACells backend] GPU detected → use_gpu=True, use_sparse=False
# [SEACells backend] installed SEACells has no `use_sparse` param — dropping it
# Welcome to SEACells GPU!
# Using provided list of initial archetypes
# Randomly initialized A matrix.
# Setting convergence threshold at 0.37461
# Starting iteration 1.
# Completed iteration 1.
# Converged after 9 iterations.
# Starting iteration 10.
# Completed iteration 10.
# 100%|██████████| 220/220 [00:00<00:00, 743.23it/s]
# saving to:  /content/drive/MyDrive/models/pancreas/seacell_X_combat
#   delta kept: X=no (deduped), 1 layer(s), 0 varm, 3 obsm, 2 obsp, obs cols ['SEACell']
# Loading SEACell from /content/drive/MyDrive/models/pancreas/seacell_X_combat ...
# [seacell] unused protos: 0/220 (0.00%)
# [seacell] mean cell-type purity: 0.9527  (size-weighted: 0.9689 ± 0.0692)
# [seacell] mean batch entropy: 0.7405  (size-weighted: 0.7837 ± 0.5089)
# [seacell] coverage: 0.8571
# [seacell] modularity: 0.5351
# [seacell] per-batch modularity: mean=0.4601, std=0.0684
# [aff_dc_compactness] looking for graph at: ./graphs/affinity_pancreas16382_ncomp50_kneighbors50_arbf.pkl
# [aff_dc_compactness] mean=0.2918 | saved to /content/drive/MyDrive/models/pancreas/seacell_X_combat/aff_dc_compactness.csv
# [seacell] saved metrics to /content/drive/MyDrive/models/pancreas/seacell_X_combat
# SEACell UMAP data saved to /content/drive/MyDrive/models/pancreas/seacell_X_combat
# [pancreas] canonical ARBF-on-PCA affinity graph loaded from ./graphs/affinity_pancreas16382_ncomp50_kneighbors50_arbf.pkl (nnz=1171528) -- caching for reuse across all methods for this dataset.
# [/content/drive/MyDrive/models/pancreas/seacell_X_combat] modularity recomputed against canonical graph: mean_modularity_batch=0.3765649413877207 +/- 0.08928125703991625 (was 0.4601307456719233), K_target=220
# Loading SEACell from /content/drive/MyDrive/models/pancreas/seacell_X_combat ...
# Processing batches, calcualte centroids and pairwise distances
#   0%|          | 0/9 [00:00<?, ?it/s]
# Deleted: tmp_3e83745d.h5ad
# [seacell task2] coverage: 0.8571
# [seacell task2] scgraph_corr_avg: 0.8366
# [seacell task2] scgraph_corr_std: 0.0337
#   [leiden oversegment] resolution=1.0000 -> 14 clusters (need >= 220)
#   [leiden oversegment] resolution=2.0000 -> 20 clusters (need >= 220)
#   [leiden oversegment] resolution=4.0000 -> 35 clusters (need >= 220)
#   [leiden oversegment] resolution=8.0000 -> 69 clusters (need >= 220)
#   [leiden oversegment] resolution=16.0000 -> 134 clusters (need >= 220)
#   [leiden oversegment] resolution=32.0000 -> 320 clusters (need >= 220)
#   [leiden merge] -> 310 clusters (target 220)
#   [leiden merge] -> 300 clusters (target 220)
#   [leiden merge] -> 290 clusters (target 220)
#   [leiden merge] -> 280 clusters (target 220)
#   [leiden merge] -> 270 clusters (target 220)
#   [leiden merge] -> 260 clusters (target 220)
#   [leiden merge] -> 250 clusters (target 220)
#   [leiden merge] -> 240 clusters (target 220)
#   [leiden merge] -> 230 clusters (target 220)
#   [leiden merge] -> 225 clusters (target 220)
#   [leiden merge] -> 224 clusters (target 220)
#   [leiden merge] -> 223 clusters (target 220)
#   [leiden merge] -> 222 clusters (target 220)
#   [leiden merge] -> 221 clusters (target 220)
#   [leiden merge] -> 220 clusters (target 220)
# [leiden merge-down] final: 220 clusters (target 220)
# [leiden_X_combat_K220] unused protos: 0/220 (0.00%)
# [leiden_X_combat_K220] mean cell-type purity: 0.9693  (size-weighted: 0.9680 ± 0.0695)
# [leiden_X_combat_K220] mean batch entropy: 0.7224  (size-weighted: 1.1004 ± 0.6651)
# [leiden_X_combat_K220] coverage: 0.9286
# [leiden_X_combat_K220] modularity: 0.6005
# [leiden_X_combat_K220] per-batch modularity: mean=0.5332, std=0.1520
# [aff_dc_compactness] looking for graph at: ./graphs/affinity_pancreas16382_ncomp50_kneighbors50_arbf.pkl
# [aff_dc_compactness] mean=0.1713 | saved to /content/drive/MyDrive/models/pancreas/leiden_X_combat_K220/aff_dc_compactness.csv
# [leiden_X_combat_K220] saved metrics to /content/drive/MyDrive/models/pancreas/leiden_X_combat_K220
# [/content/drive/MyDrive/models/pancreas/leiden_X_combat_K220] modularity recomputed against canonical graph: mean_modularity_batch=0.5332420091258472 +/- 0.15199864445219383 (was 0.5332420091258472), K_target=220
# 100%|██████████| 220/220 [00:00<00:00, 909.01it/s]
# Processing batches, calcualte centroids and pairwise distances
#   0%|          | 0/9 [00:00<?, ?it/s]
# WARNING: task2 failed for leiden_X_combat: ValueError: XA must be a 2-dimensional array. -- keeping task1 results, continuing.
# [leiden_X_combat] umap_cells.csv / umap_protos.csv saved to /content/drive/MyDrive/models/pancreas/leiden_X_combat_K220
# [pancreas] leiden-on-X_combat saved to /content/drive/MyDrive/models/pancreas/leiden_X_combat_K220
#
# [pancreas] rare-type kNN purity by method: {'combat': 0.631, 'raw_pca': 0.499}
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/16382 [00:00<?, ?it/s]
# Making graph symmetric...
# Parameter graph_construction = union being used to build KNN graph...
# Computing RBF kernel...
#   0%|          | 0/16382 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/16382 [00:00<?, ?it/s]
# Constructing CSR matrix...
# [pancreas] Raw PCA (uncorrected) (d=50): 0.385 +/- 0.164 (n=8 batches)
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/16382 [00:00<?, ?it/s]
# Making graph symmetric...
# Parameter graph_construction = union being used to build KNN graph...
# Computing RBF kernel...
#   0%|          | 0/16382 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/16382 [00:00<?, ?it/s]
# Constructing CSR matrix...
# [pancreas] scPoli (Stage-1) (d=8): 0.512 +/- 0.162 (n=8 batches)
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/16382 [00:00<?, ?it/s]
# Making graph symmetric...
# Parameter graph_construction = union being used to build KNN graph...
# Computing RBF kernel...
#   0%|          | 0/16382 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/16382 [00:00<?, ?it/s]
# Constructing CSR matrix...
# [pancreas] scProto (d=8): 0.454 +/- 0.184 (n=8 batches)
# [pancreas] affinity purity saved to /content/drive/MyDrive/models/pancreas/rare_affinity_purity_pancreas.json

# %% [markdown]
# ## Run: Lung

# %%
lung_results = run_all_baselines_for_dataset(
    'lung', correction_methods=CORRECTION_METHODS, skip_if_exists=SKIP_IF_EXISTS,
    run_seacells=RUN_SEACELLS, run_leiden=RUN_LEIDEN,
)
# Out:
# dataset is None, loading lung
# loading lung data
# ✅ Already subsetted to HVGs (4000 genes).
# stage1_latent_extract_ds-lung_aff-arbf_cvae_e50_v31
# Embedding dictionary:
#  	Num conditions: [16]
#  	Embedding dim: [10]
# Encoder Architecture:
# 	Input Layer in, out and cond: 4000 64 10
# 	Mean/Var Layer in/out: 64 8
# Decoder Architecture:
# 	First Layer in, out and cond:  8 64 10
# 	Output Layer in/out:  64 4000
#
# 📊 Affinity: wdeg[min/mean/max]=5.255/24.467/119.300, effk_med=63.8, mutual=100.00%
# adam
# Loaded pretrain checkpoint from /content/drive/MyDrive/models/lung/pretrain/pretrain_ds-lung_cvae_e50/pretrain_checkpoint.pth
#   pretrain_params: {'dataset_id': 'lung', 'cvae_epochs': 50, 'batch_size': 1024, 'latent_dims': 8, 'l2norm': 1, 'model_type': 'gm', 'beta': 0.3, 'condition_key': 'batch'}
#   0%|          | 0/32 [00:00<?, ?it/s]
# [lung] Stage-1 latent: 32472 cells x 8 dims
# dataset is None, loading lung
# loading lung data
# ✅ Already subsetted to HVGs (4000 genes).
# proto_umap_ds-lung_prtInit-wayp_aff-arbf_lprec0.01_usim-prot_cvae_e50_ecal1_lpu0.1_pum-ema_lna1_nagg-max_upm-dotp_v31
# Embedding dictionary:
#  	Num conditions: [16]
#  	Embedding dim: [10]
# Encoder Architecture:
# 	Input Layer in, out and cond: 4000 64 10
# 	Mean/Var Layer in/out: 64 8
# Decoder Architecture:
# 	First Layer in, out and cond:  8 64 10
# 	Output Layer in/out:  64 4000
#
# 📊 Affinity: wdeg[min/mean/max]=5.255/24.467/119.300, effk_med=63.8, mutual=100.00%
# adam
# Loaded pretrain checkpoint from /content/drive/MyDrive/models/lung/pretrain/pretrain_ds-lung_cvae_e50/pretrain_checkpoint.pth
#   pretrain_params: {'dataset_id': 'lung', 'cvae_epochs': 50, 'batch_size': 1024, 'latent_dims': 8, 'l2norm': 1, 'model_type': 'gm', 'beta': 0.3, 'condition_key': 'batch'}
# 📊 EdgeDataset: 2447924 edges
#    Weight range: [0.0137, 0.9491]
#    umap_steps_per_epoch=500 → 512000 edges/epoch (of 2447924 total)
# 📐 UMAP kernel: min_dist=0.5, spread=1.0 -> a=0.5830, b=1.3342
# Starting edge-centric UMAP training (similarity=proto)
#    min_dist=0.5, spread=1.0, neg_rate=5
#    lambda_umap=1, lambda_recon=0, lambda_kl=0, lambda_proto_recon=0.01, lambda_r1r2=0.0
#    nassoc: λ=1, agg=max, diag=ON [(m-1)²], offdiag=[m²]
# Loaded UMAP checkpoint from /content/drive/MyDrive/models//lung/proto_umap_ds-lung_prtInit-wayp_aff-arbf_lprec0.01_usim-prot_cvae_e50_ecal1_lpu0.1_pum-ema_lna1_nagg-max_upm-dotp_v31/umap_checkpoint.pth (epoch 3)
#   0%|          | 0/32 [00:00<?, ?it/s]
# === [lung] batch-correction method: combat ===
# [lung] combat: cached embedding to /content/drive/MyDrive/models/lung/_cache_X_combat_emb.npy
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/32472 [00:00<?, ?it/s]
# Making graph symmetric...
# Parameter graph_construction = union being used to build KNN graph...
# Computing RBF kernel...
#   0%|          | 0/32472 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/32472 [00:00<?, ?it/s]
# Constructing CSR matrix...
# [waypoint init] N=32472  k=300  n_eigs=10  nnz=2621982  nnz/row=80.7
# [waypoint init] computing diffusion map ...
# [waypoint init] diffusion map done — 10 eigenvectors
# waypoint MaxMin: 100%|██████████| 299/299 [00:00<00:00, 4948.05archetype/s]
# [waypoint init] selected 300 archetype seed cells
# [SEACells backend] GPU detected → use_gpu=True, use_sparse=False
# [SEACells backend] installed SEACells has no `use_sparse` param — dropping it
# Welcome to SEACells GPU!
# Using provided list of initial archetypes
# Randomly initialized A matrix.
# Setting convergence threshold at 0.51499
# Starting iteration 1.
# Completed iteration 1.
# Converged after 9 iterations.
# Starting iteration 10.
# Completed iteration 10.
# Converged after 10 iterations.
# 100%|██████████| 300/300 [00:00<00:00, 341.45it/s]
# saving to:  /content/drive/MyDrive/models/lung/seacell_X_combat
#   delta kept: X=no (deduped), 1 layer(s), 0 varm, 1 obsm, 2 obsp, obs cols ['SEACell']
# Loading SEACell from /content/drive/MyDrive/models/lung/seacell_X_combat ...
# [seacell] unused protos: 0/300 (0.00%)
# [seacell] mean cell-type purity: 0.8948  (size-weighted: 0.8848 ± 0.1575)
# [seacell] mean batch entropy: 0.7110  (size-weighted: 0.7916 ± 0.5561)
# [seacell] coverage: 1.0000
# [seacell] modularity: 0.5844
# [seacell] per-batch modularity: mean=0.5232, std=0.0297
# [aff_dc_compactness] looking for graph at: ./graphs/affinity_lung32472_ncomp50_kneighbors50_arbf.pkl
# [aff_dc_compactness] mean=5.8797 | saved to /content/drive/MyDrive/models/lung/seacell_X_combat/aff_dc_compactness.csv
# [seacell] saved metrics to /content/drive/MyDrive/models/lung/seacell_X_combat
# SEACell UMAP data saved to /content/drive/MyDrive/models/lung/seacell_X_combat
# [lung] canonical ARBF-on-PCA affinity graph loaded from ./graphs/affinity_lung32472_ncomp50_kneighbors50_arbf.pkl (nnz=2480396) -- caching for reuse across all methods for this dataset.
# [/content/drive/MyDrive/models/lung/seacell_X_combat] modularity recomputed against canonical graph: mean_modularity_batch=0.4064212197721004 +/- 0.0429779704328677 (was 0.5232198045526575), K_target=300
# Loading SEACell from /content/drive/MyDrive/models/lung/seacell_X_combat ...
# Processing batches, calcualte centroids and pairwise distances
#   0%|          | 0/16 [00:00<?, ?it/s]
# Deleted: tmp_dc2440a1.h5ad
# [seacell task2] coverage: 1.0000
# [seacell task2] scgraph_corr_avg: 0.8694
# [seacell task2] scgraph_corr_std: 0.0845
#   [leiden oversegment] resolution=1.0000 -> 25 clusters (need >= 300)
#   [leiden oversegment] resolution=2.0000 -> 33 clusters (need >= 300)
#   [leiden oversegment] resolution=4.0000 -> 51 clusters (need >= 300)
#   [leiden oversegment] resolution=8.0000 -> 81 clusters (need >= 300)
#   [leiden oversegment] resolution=16.0000 -> 127 clusters (need >= 300)
#   [leiden oversegment] resolution=32.0000 -> 252 clusters (need >= 300)
#   [leiden oversegment] resolution=64.0000 -> 611 clusters (need >= 300)
#   [leiden merge] -> 610 clusters (target 300)
#   [leiden merge] -> 600 clusters (target 300)
#   [leiden merge] -> 590 clusters (target 300)
#   [leiden merge] -> 580 clusters (target 300)
#   [leiden merge] -> 570 clusters (target 300)
#   [leiden merge] -> 560 clusters (target 300)
#   [leiden merge] -> 550 clusters (target 300)
#   [leiden merge] -> 540 clusters (target 300)
#   [leiden merge] -> 530 clusters (target 300)
#   [leiden merge] -> 520 clusters (target 300)
#   [leiden merge] -> 510 clusters (target 300)
#   [leiden merge] -> 500 clusters (target 300)
#   [leiden merge] -> 490 clusters (target 300)
#   [leiden merge] -> 480 clusters (target 300)
#   [leiden merge] -> 470 clusters (target 300)
#   [leiden merge] -> 460 clusters (target 300)
#   [leiden merge] -> 450 clusters (target 300)
#   [leiden merge] -> 440 clusters (target 300)
#   [leiden merge] -> 430 clusters (target 300)
#   [leiden merge] -> 420 clusters (target 300)
#   [leiden merge] -> 410 clusters (target 300)
#   [leiden merge] -> 400 clusters (target 300)
#   [leiden merge] -> 390 clusters (target 300)
#   [leiden merge] -> 380 clusters (target 300)
#   [leiden merge] -> 370 clusters (target 300)
#   [leiden merge] -> 360 clusters (target 300)
#   [leiden merge] -> 350 clusters (target 300)
#   [leiden merge] -> 340 clusters (target 300)
#   [leiden merge] -> 330 clusters (target 300)
#   [leiden merge] -> 320 clusters (target 300)
#   [leiden merge] -> 310 clusters (target 300)
#   [leiden merge] -> 305 clusters (target 300)
#   [leiden merge] -> 304 clusters (target 300)
#   [leiden merge] -> 303 clusters (target 300)
#   [leiden merge] -> 302 clusters (target 300)
#   [leiden merge] -> 301 clusters (target 300)
#   [leiden merge] -> 300 clusters (target 300)
# [leiden merge-down] final: 300 clusters (target 300)
# [leiden_X_combat_K300] unused protos: 0/300 (0.00%)
# [leiden_X_combat_K300] mean cell-type purity: 0.8749  (size-weighted: 0.8100 ± 0.1987)
# [leiden_X_combat_K300] mean batch entropy: 0.6874  (size-weighted: 1.0949 ± 0.5962)
# [leiden_X_combat_K300] coverage: 1.0000
# [leiden_X_combat_K300] modularity: 0.7274
# [leiden_X_combat_K300] per-batch modularity: mean=0.5540, std=0.0777
# [aff_dc_compactness] looking for graph at: ./graphs/affinity_lung32472_ncomp50_kneighbors50_arbf.pkl
# [aff_dc_compactness] mean=2.6183 | saved to /content/drive/MyDrive/models/lung/leiden_X_combat_K300/aff_dc_compactness.csv
# [leiden_X_combat_K300] saved metrics to /content/drive/MyDrive/models/lung/leiden_X_combat_K300
# [/content/drive/MyDrive/models/lung/leiden_X_combat_K300] modularity recomputed against canonical graph: mean_modularity_batch=0.5539883393595644 +/- 0.0777368786224248 (was 0.5539883393595644), K_target=300
# 100%|██████████| 300/300 [00:00<00:00, 451.05it/s]
# Processing batches, calcualte centroids and pairwise distances
#   0%|          | 0/16 [00:00<?, ?it/s]
# WARNING: task2 failed for leiden_X_combat: ValueError: XA must be a 2-dimensional array. -- keeping task1 results, continuing.
# [leiden_X_combat] umap_cells.csv / umap_protos.csv saved to /content/drive/MyDrive/models/lung/leiden_X_combat_K300
# [lung] leiden-on-X_combat saved to /content/drive/MyDrive/models/lung/leiden_X_combat_K300
#
# [lung] rare-type kNN purity by method: {'combat': 0.83, 'raw_pca': 0.912}
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/32472 [00:00<?, ?it/s]
# Making graph symmetric...
# Parameter graph_construction = union being used to build KNN graph...
# Computing RBF kernel...
#   0%|          | 0/32472 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/32472 [00:00<?, ?it/s]
# Constructing CSR matrix...
# [lung] Raw PCA (uncorrected) (d=50): 0.559 +/- 0.194 (n=15 batches)
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/32472 [00:00<?, ?it/s]
# Making graph symmetric...
# Parameter graph_construction = union being used to build KNN graph...
# Computing RBF kernel...
#   0%|          | 0/32472 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/32472 [00:00<?, ?it/s]
# Constructing CSR matrix...
# [lung] scPoli (Stage-1) (d=8): 0.550 +/- 0.149 (n=15 batches)
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/32472 [00:00<?, ?it/s]
# Making graph symmetric...
# Parameter graph_construction = union being used to build KNN graph...
# Computing RBF kernel...
#   0%|          | 0/32472 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/32472 [00:00<?, ?it/s]
# Constructing CSR matrix...
# [lung] scProto (d=8): 0.586 +/- 0.208 (n=15 batches)
# [lung] affinity purity saved to /content/drive/MyDrive/models/lung/rare_affinity_purity_lung.json

# %% [markdown]
# ## Run: PBMC (Immune)

# %%
immune_results = run_all_baselines_for_dataset(
    'pbmc-immune', correction_methods=CORRECTION_METHODS, skip_if_exists=SKIP_IF_EXISTS,
    run_seacells=RUN_SEACELLS, run_leiden=RUN_LEIDEN,
)
# Out:
# dataset is None, loading pbmc-immune
# loading pbmc-immune data
# ✅ Already subsetted to HVGs (4000 genes).
# stage1_latent_extract_aff-arbf_cvae_e50_v31
# Embedding dictionary:
#  	Num conditions: [5]
#  	Embedding dim: [10]
# Encoder Architecture:
# 	Input Layer in, out and cond: 4000 64 10
# 	Mean/Var Layer in/out: 64 8
# Decoder Architecture:
# 	First Layer in, out and cond:  8 64 10
# 	Output Layer in/out:  64 4000
#
# 📊 Affinity: wdeg[min/mean/max]=1.667/25.923/299.545, effk_med=62.9, mutual=100.00%
# adam
# Loaded pretrain checkpoint from /content/drive/MyDrive/models/pbmc-immune/pretrain/pretrain_cvae_e50/pretrain_checkpoint.pth
#   pretrain_params: {'dataset_id': 'pbmc-immune', 'cvae_epochs': 50, 'batch_size': 1024, 'latent_dims': 8, 'l2norm': 1, 'model_type': 'gm', 'beta': 0.3, 'condition_key': 'study'}
#   0%|          | 0/33 [00:00<?, ?it/s]
# [pbmc-immune] Stage-1 latent: 33506 cells x 8 dims
# dataset is None, loading pbmc-immune
# loading pbmc-immune data
# ✅ Already subsetted to HVGs (4000 genes).
# proto_umap_prtInit-wayp_aff-arbf_lprec0.01_usim-prot_cvae_e50_ecal1_lpu0.1_pum-ema_lna1_nagg-max_upm-dotp_v31
# Embedding dictionary:
#  	Num conditions: [5]
#  	Embedding dim: [10]
# Encoder Architecture:
# 	Input Layer in, out and cond: 4000 64 10
# 	Mean/Var Layer in/out: 64 8
# Decoder Architecture:
# 	First Layer in, out and cond:  8 64 10
# 	Output Layer in/out:  64 4000
#
# 📊 Affinity: wdeg[min/mean/max]=1.667/25.923/299.545, effk_med=62.9, mutual=100.00%
# adam
# Loaded pretrain checkpoint from /content/drive/MyDrive/models/pbmc-immune/pretrain/pretrain_cvae_e50/pretrain_checkpoint.pth
#   pretrain_params: {'dataset_id': 'pbmc-immune', 'cvae_epochs': 50, 'batch_size': 1024, 'latent_dims': 8, 'l2norm': 1, 'model_type': 'gm', 'beta': 0.3, 'condition_key': 'study'}
# 📊 EdgeDataset: 2590828 edges
#    Weight range: [0.0050, 0.9224]
#    umap_steps_per_epoch=500 → 512000 edges/epoch (of 2590828 total)
# 📐 UMAP kernel: min_dist=0.5, spread=1.0 -> a=0.5830, b=1.3342
# Starting edge-centric UMAP training (similarity=proto)
#    min_dist=0.5, spread=1.0, neg_rate=5
#    lambda_umap=1, lambda_recon=0, lambda_kl=0, lambda_proto_recon=0.01, lambda_r1r2=0.0
#    nassoc: λ=1, agg=max, diag=ON [(m-1)²], offdiag=[m²]
# Loaded UMAP checkpoint from /content/drive/MyDrive/models//pbmc-immune/proto_umap_prtInit-wayp_aff-arbf_lprec0.01_usim-prot_cvae_e50_ecal1_lpu0.1_pum-ema_lna1_nagg-max_upm-dotp_v31/umap_checkpoint.pth (epoch 3)
#   0%|          | 0/33 [00:00<?, ?it/s]
# === [pbmc-immune] batch-correction method: combat ===
# [pbmc-immune] combat: cached embedding to /content/drive/MyDrive/models/pbmc-immune/_cache_X_combat_emb.npy
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Making graph symmetric...
# Parameter graph_construction = union being used to build KNN graph...
# Computing RBF kernel...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Constructing CSR matrix...
# [waypoint init] N=33506  k=300  n_eigs=10  nnz=2728082  nnz/row=81.4
# [waypoint init] computing diffusion map ...
# [waypoint init] diffusion map done — 10 eigenvectors
# waypoint MaxMin: 100%|██████████| 299/299 [00:00<00:00, 4786.72archetype/s]
# [waypoint init] selected 300 archetype seed cells
# [SEACells backend] GPU detected → use_gpu=True, use_sparse=False
# [SEACells backend] installed SEACells has no `use_sparse` param — dropping it
# Welcome to SEACells GPU!
# Using provided list of initial archetypes
# Randomly initialized A matrix.
# Setting convergence threshold at 0.55738
# Starting iteration 1.
# Completed iteration 1.
# Starting iteration 10.
# Completed iteration 10.
# Converged after 10 iterations.
# 100%|██████████| 300/300 [00:00<00:00, 350.12it/s]
# saving to:  /content/drive/MyDrive/models/pbmc-immune/seacell_X_combat
#   delta kept: X=no (deduped), 1 layer(s), 0 varm, 3 obsm, 2 obsp, obs cols ['SEACell']
# Loading SEACell from /content/drive/MyDrive/models/pbmc-immune/seacell_X_combat ...
# [seacell] unused protos: 0/300 (0.00%)
# [seacell] mean cell-type purity: 0.8939  (size-weighted: 0.8774 ± 0.1407)
# [seacell] mean batch entropy: 0.3010  (size-weighted: 0.4250 ± 0.3769)
# [seacell] coverage: 1.0000
# [seacell] modularity: 0.4479
# [seacell] per-batch modularity: mean=0.4292, std=0.0717
# [aff_dc_compactness] looking for graph at: ./graphs/affinity_pbmc-immune33506_ncomp50_kneighbors50_arbf.pkl
# [aff_dc_compactness] mean=1.1469 | saved to /content/drive/MyDrive/models/pbmc-immune/seacell_X_combat/aff_dc_compactness.csv
# [seacell] saved metrics to /content/drive/MyDrive/models/pbmc-immune/seacell_X_combat
# SEACell UMAP data saved to /content/drive/MyDrive/models/pbmc-immune/seacell_X_combat
# [pbmc-immune] canonical ARBF-on-PCA affinity graph loaded from ./graphs/affinity_pbmc-immune33506_ncomp50_kneighbors50_arbf.pkl (nnz=2624382) -- caching for reuse across all methods for this dataset.
# [/content/drive/MyDrive/models/pbmc-immune/seacell_X_combat] modularity recomputed against canonical graph: mean_modularity_batch=0.30494087273668197 +/- 0.047675376804797345 (was 0.4291621260165098), K_target=300
# Loading SEACell from /content/drive/MyDrive/models/pbmc-immune/seacell_X_combat ...
# Processing batches, calcualte centroids and pairwise distances
#   0%|          | 0/5 [00:00<?, ?it/s]
# Deleted: tmp_21adfc35.h5ad
# [seacell task2] coverage: 1.0000
# [seacell task2] scgraph_corr_avg: 0.8503
# [seacell task2] scgraph_corr_std: 0.0652
#   [leiden oversegment] resolution=1.0000 -> 21 clusters (need >= 300)
#   [leiden oversegment] resolution=2.0000 -> 30 clusters (need >= 300)
#   [leiden oversegment] resolution=4.0000 -> 44 clusters (need >= 300)
#   [leiden oversegment] resolution=8.0000 -> 80 clusters (need >= 300)
#   [leiden oversegment] resolution=16.0000 -> 199 clusters (need >= 300)
#   [leiden oversegment] resolution=32.0000 -> 519 clusters (need >= 300)
#   [leiden merge] -> 510 clusters (target 300)
#   [leiden merge] -> 500 clusters (target 300)
#   [leiden merge] -> 490 clusters (target 300)
#   [leiden merge] -> 480 clusters (target 300)
#   [leiden merge] -> 470 clusters (target 300)
#   [leiden merge] -> 460 clusters (target 300)
#   [leiden merge] -> 450 clusters (target 300)
#   [leiden merge] -> 440 clusters (target 300)
#   [leiden merge] -> 430 clusters (target 300)
#   [leiden merge] -> 420 clusters (target 300)
#   [leiden merge] -> 410 clusters (target 300)
#   [leiden merge] -> 400 clusters (target 300)
#   [leiden merge] -> 390 clusters (target 300)
#   [leiden merge] -> 380 clusters (target 300)
#   [leiden merge] -> 370 clusters (target 300)
#   [leiden merge] -> 360 clusters (target 300)
#   [leiden merge] -> 350 clusters (target 300)
#   [leiden merge] -> 340 clusters (target 300)
#   [leiden merge] -> 330 clusters (target 300)
#   [leiden merge] -> 320 clusters (target 300)
#   [leiden merge] -> 310 clusters (target 300)
#   [leiden merge] -> 305 clusters (target 300)
#   [leiden merge] -> 304 clusters (target 300)
#   [leiden merge] -> 303 clusters (target 300)
#   [leiden merge] -> 302 clusters (target 300)
#   [leiden merge] -> 301 clusters (target 300)
#   [leiden merge] -> 300 clusters (target 300)
# [leiden merge-down] final: 300 clusters (target 300)
# [leiden_X_combat_K300] unused protos: 0/300 (0.00%)
# [leiden_X_combat_K300] mean cell-type purity: 0.8021  (size-weighted: 0.8412 ± 0.1438)
# [leiden_X_combat_K300] mean batch entropy: 0.6494  (size-weighted: 0.6393 ± 0.4593)
# [leiden_X_combat_K300] coverage: 1.0000
# [leiden_X_combat_K300] modularity: 0.6540
# [leiden_X_combat_K300] per-batch modularity: mean=0.5756, std=0.1663
# [aff_dc_compactness] looking for graph at: ./graphs/affinity_pbmc-immune33506_ncomp50_kneighbors50_arbf.pkl
# [aff_dc_compactness] mean=0.2926 | saved to /content/drive/MyDrive/models/pbmc-immune/leiden_X_combat_K300/aff_dc_compactness.csv
# [leiden_X_combat_K300] saved metrics to /content/drive/MyDrive/models/pbmc-immune/leiden_X_combat_K300
# [/content/drive/MyDrive/models/pbmc-immune/leiden_X_combat_K300] modularity recomputed against canonical graph: mean_modularity_batch=0.5755652185916864 +/- 0.16633102146498027 (was 0.5755652185916864), K_target=300
# 100%|██████████| 300/300 [00:00<00:00, 483.98it/s]
# Processing batches, calcualte centroids and pairwise distances
#   0%|          | 0/5 [00:00<?, ?it/s]
# WARNING: task2 failed for leiden_X_combat: ValueError: XA must be a 2-dimensional array. -- keeping task1 results, continuing.
# [leiden_X_combat] umap_cells.csv / umap_protos.csv saved to /content/drive/MyDrive/models/pbmc-immune/leiden_X_combat_K300
# [pbmc-immune] leiden-on-X_combat saved to /content/drive/MyDrive/models/pbmc-immune/leiden_X_combat_K300
#
# [pbmc-immune] rare-type kNN purity by method: {'combat': 0.793, 'raw_pca': 0.776}
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Making graph symmetric...
# Parameter graph_construction = union being used to build KNN graph...
# Computing RBF kernel...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Constructing CSR matrix...
# [pbmc-immune] Raw PCA (uncorrected) (d=50): 0.827 +/- 0.050 (n=5 batches)
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Making graph symmetric...
# Parameter graph_construction = union being used to build KNN graph...
# Computing RBF kernel...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Constructing CSR matrix...
# [pbmc-immune] scPoli (Stage-1) (d=8): 0.841 +/- 0.074 (n=5 batches)
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Making graph symmetric...
# Parameter graph_construction = union being used to build KNN graph...
# Computing RBF kernel...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Constructing CSR matrix...
# [pbmc-immune] ComBat (d=50): 0.855 +/- 0.067 (n=5 batches)
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Making graph symmetric...
# Parameter graph_construction = union being used to build KNN graph...
# Computing RBF kernel...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Constructing CSR matrix...
# [pbmc-immune] scProto (d=8): 0.849 +/- 0.085 (n=5 batches)
# [pbmc-immune] affinity purity saved to /content/drive/MyDrive/models/pbmc-immune/rare_affinity_purity_pbmc-immune.json

# %% [markdown]
# ## Results comparison
#
# Pulls in **every** existing run under `MODEL_DIR/{ds}/*` (scProto, SEACells(PCA), plus
# whatever's already been computed by the Harmony notebook, alongside the new ComBat
# baselines here) -- `load_task1_multi` / `rare_celltype_purity_table` just scan folders +
# `metrics.json` / `umap_cells.csv`, they don't need to know which notebook produced them.
#
# Harmony is included in the comparison tables below (via `HARMONY_DIM`) purely as a
# READ of whatever's already on disk from the other notebook -- it is never (re)computed
# here. If the Harmony notebook hasn't been run yet, those rows are simply absent, not an
# error.
#
# **Reminder:** the modularity column is scored against the arbf-on-PCA graph that only
# scProto is trained to match -- treat it as a plausibility check, not the primary
# evidence. Purity, batch entropy, and especially the rare-cell coverage/homogeneity
# table (further down) are the fair, post-hoc comparison -- see the intro cell's note on
# ComBat's two structural limitations for what to look for there specifically.

# %%
dataset_display_names = {'pancreas': 'Pancreas', 'lung': 'Lung', 'pbmc-immune': 'Immune'}

# scProto runs verified against the paper's published numbers via generate_tables.ipynb
# (the actual notebook used to build the paper's tables) -- bit-identical to the
# published numbers on multiple metrics simultaneously per dataset. Same three
# canonical run names the Harmony notebook uses (this is the SAME scProto model,
# just compared against a different baseline here).
SCPROTO_CANONICAL_RUNS = {
    'proto_umap_ds-panc_NP220_prtInit-wayp_aff-arbf_lprec0.01_usim-prot_cvae_e50_ecal1_lpu0.1_pum-ema_lna1_nagg-max_upm-dotp_v31',
    'proto_umap_ds-lung_prtInit-wayp_aff-arbf_lprec0.01_usim-prot_cvae_e50_ecal1_lpu0.1_pum-ema_lna1_nagg-max_upm-dotp_v31',
    'proto_umap_prtInit-wayp_aff-arbf_lprec0.01_usim-prot_cvae_e50_ecal1_lpu0.1_pum-ema_lna1_nagg-max_upm-dotp_v31',
}

SCPROTO_KEY = extract_model_key(next(iter(SCPROTO_CANONICAL_RUNS)))
assert all(extract_model_key(r) == SCPROTO_KEY for r in SCPROTO_CANONICAL_RUNS), (
    "SCPROTO_CANONICAL_RUNS entries no longer normalize to one shared key -- "
    "extract_model_key's stripping patterns changed; update the scProto matching logic."
)

MODEL_KEYWORDS = {SCPROTO_KEY: 'scProto'}
MODEL_KEYWORDS['seacell'] = 'SEACells (PCA)'

# ComBat: generic tag, no dimension-matching needed (unlike Harmony -- ComBat is
# corrected-then-PCA'd at a fixed n_comps=50, same as scVI/stage1z).
for _method in CORRECTION_METHODS:
    _disp = METHOD_DISPLAY_NAMES[_method]
    MODEL_KEYWORDS[f'seacell_X_{_method}'] = f'SEACells ({_disp})'
    MODEL_KEYWORDS[f'leiden_X_{_method}']  = f'Leiden ({_disp})'

# Harmony -- READ ONLY, pulled in for side-by-side comparison if the other notebook has
# already produced it (see 'Results comparison' markdown above). HARMONY_DIM must match
# scProto's actual latent_dims (currently 8 for all three datasets, per the Stage-1
# pretrain params) -- a literal string match, not computed dynamically.
HARMONY_DIM = 8
MODEL_KEYWORDS[f'seacell_X_harmony_d{HARMONY_DIM}'] = 'SEACells (Harmony)'
MODEL_KEYWORDS[f'leiden_X_harmony_d{HARMONY_DIM}']  = 'Leiden (Harmony)'

# %%
def _keep_and_rename_runs(df, model_keywords=MODEL_KEYWORDS):
    # Filter load_task1_multi's output down to just the runs in model_keywords, and
    # collapse each method's per-dataset '_K{n}' folder-name suffix into ONE shared
    # display row per method. Identical logic to the Harmony notebook's version of this
    # helper -- kept as a local copy rather than imported, since these notebooks are
    # meant to run independently in parallel sessions.
    runs = df.index.get_level_values('run')
    datasets = df.index.get_level_values('dataset')
    stripped = runs.str.replace(r'_K\d+$', '', regex=True)
    keep_mask = stripped.isin(model_keywords)

    kept_runs, kept_datasets = runs[keep_mask], datasets[keep_mask]
    kept_display = stripped[keep_mask].map(model_keywords)

    out = df[keep_mask].copy()
    out.index = pd.MultiIndex.from_arrays([kept_datasets, kept_display], names=['dataset', 'run'])

    dupe_mask = out.index.duplicated(keep='first')
    if dupe_mask.any():
        stale = list(zip(kept_datasets[dupe_mask], kept_runs[dupe_mask], kept_display[dupe_mask]))
        print(f"WARNING: dropped {dupe_mask.sum()} duplicate (dataset, method) row(s) -- "
              f"likely a stale run at an old K value still on disk. "
              f"(dataset, on-disk folder, display name): {stale}")
        out = out[~dupe_mask]
    return out

# --- Table 1 (community structure / batch integration): modularity, batch entropy, purity ---
df_task1 = load_task1_multi(RNA_SEQ_DATASETS, metrics=TASK1_METRICS)
df_task1 = _keep_and_rename_runs(df_task1)
show_table(df_task1, metrics=TASK1_METRICS, dataset_display_names=dataset_display_names)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_38512/1205383410.py in <cell line: 0>()
#      63
#      64 # --- Table 1 (community structure / batch integration): modularity, batch entropy, purity ---
# ---> 65 df_task1 = load_task1_multi(RNA_SEQ_DATASETS, metrics=TASK1_METRICS)
#      66 df_task1 = _keep_and_rename_runs(df_task1)
#      67 show_table(df_task1, metrics=TASK1_METRICS, dataset_display_names=dataset_display_names)
#
# /content/drive/MyDrive/codes/interpretable-prototype/interpretable_ssl/evaluation/metric_helpers/result_tables.py in load_task1_multi(ds_ids, metrics)
#     266     dfs = []
#     267     for ds in ds_ids:
# --> 268         df = load_task1_df(ds, metrics)
#     269         if df.empty:
#     270             continue
#
# /content/drive/MyDrive/codes/interpretable-prototype/interpretable_ssl/evaluation/metric_helpers/result_tables.py in load_task1_df(ds_id, metrics)
#     234         DataFrame with model config names as rows and metrics as columns.
#     235     """
# --> 236     raw = load_run_metrics(ds_id)
#     237     if not raw:
#     238         print(f'No runs found for dataset "{ds_id}"')
#
# /content/drive/MyDrive/codes/interpretable-prototype/interpretable_ssl/evaluation/metric_helpers/result_tables.py in load_run_metrics(ds_id)
#     169         if os.path.exists(json_path):
#     170             with open(json_path) as f:
# --> 171                 m = json.load(f)
#     172         elif os.path.exists(npz_path):
#     173             data = np.load(npz_path, allow_pickle=True)
#
# /usr/lib/python3.12/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /usr/lib/python3.12/codecs.py in decode(self, input, final)
#
# KeyboardInterrupt:

# %%
# --- Table 2 (metacell representation quality): coverage, scGraph (DGE consistency
# turned off, see intro) ---
df_task2 = load_task1_multi(RNA_SEQ_DATASETS, metrics=TASK2_METRICS)
df_task2 = _keep_and_rename_runs(df_task2)
show_table(df_task2, metrics=TASK2_METRICS, dataset_display_names=dataset_display_names)
# Out:
# <style type="text/css">
# #T_fe383 th.col_heading.level1.col0 {
#   border-left: 2px solid #555;
# }
# #T_fe383 td.col0 {
#   border-left: 2px solid #555;
# }
# #T_fe383 th.col_heading.level1.col6 {
#   border-left: 2px solid #555;
# }
# #T_fe383 td.col6 {
#   border-left: 2px solid #555;
# }
# #T_fe383 th.col_heading.level1.col12 {
#   border-left: 2px solid #555;
# }
# #T_fe383 td.col12 {
#   border-left: 2px solid #555;
# }
# #T_fe383 th.col_heading.level0 {
#   text-align: center;
#   font-weight: bold;
#   border-bottom: 1px solid #aaa;
# }
# #T_fe383 th.col_heading.level1 {
#   text-align: center;
# }
# #T_fe383 th.row_heading {
#   text-align: left;
# }
# #T_fe383_row0_col0, #T_fe383_row0_col6, #T_fe383_row0_col12, #T_fe383_row1_col12, #T_fe383_row2_col6, #T_fe383_row2_col10, #T_fe383_row2_col12, #T_fe383_row3_col12, #T_fe383_row4_col1, #T_fe383_row4_col2, #T_fe383_row4_col5, #T_fe383_row4_col6, #T_fe383_row4_col7, #T_fe383_row4_col8, #T_fe383_row4_col9, #T_fe383_row4_col11, #T_fe383_row4_col12, #T_fe383_row4_col13, #T_fe383_row4_col14, #T_fe383_row4_col15, #T_fe383_row4_col16, #T_fe383_row5_col0, #T_fe383_row5_col3, #T_fe383_row5_col4, #T_fe383_row5_col17 {
#   font-weight: bold;
# }
# #T_fe383_row0_col17, #T_fe383_row2_col0, #T_fe383_row2_col4, #T_fe383_row2_col16, #T_fe383_row3_col0, #T_fe383_row3_col6, #T_fe383_row4_col0, #T_fe383_row4_col3, #T_fe383_row5_col1, #T_fe383_row5_col2, #T_fe383_row5_col5, #T_fe383_row5_col7, #T_fe383_row5_col8, #T_fe383_row5_col9, #T_fe383_row5_col10, #T_fe383_row5_col11, #T_fe383_row5_col12, #T_fe383_row5_col13, #T_fe383_row5_col14, #T_fe383_row5_col15 {
#   text-decoration: underline;
# }
# </style>
# <table id="T_fe383" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th id="T_fe383_level0_col0" class="col_heading level0 col0" colspan="6">Pancreas</th>
#       <th id="T_fe383_level0_col6" class="col_heading level0 col6" colspan="6">Lung</th>
#       <th id="T_fe383_level0_col12" class="col_heading level0 col12" colspan="6">Immune</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Metric</th>
#       <th id="T_fe383_level1_col0" class="col_heading level1 col0" >Coverage</th>
#       <th id="T_fe383_level1_col1" class="col_heading level1 col1" >DGE RBO</th>
#       <th id="T_fe383_level1_col2" class="col_heading level1 col2" >DGE Kendall</th>
#       <th id="T_fe383_level1_col3" class="col_heading level1 col3" >DGE Jaccard</th>
#       <th id="T_fe383_level1_col4" class="col_heading level1 col4" >scGraph Corr</th>
#       <th id="T_fe383_level1_col5" class="col_heading level1 col5" >Modularity</th>
#       <th id="T_fe383_level1_col6" class="col_heading level1 col6" >Coverage</th>
#       <th id="T_fe383_level1_col7" class="col_heading level1 col7" >DGE RBO</th>
#       <th id="T_fe383_level1_col8" class="col_heading level1 col8" >DGE Kendall</th>
#       <th id="T_fe383_level1_col9" class="col_heading level1 col9" >DGE Jaccard</th>
#       <th id="T_fe383_level1_col10" class="col_heading level1 col10" >scGraph Corr</th>
#       <th id="T_fe383_level1_col11" class="col_heading level1 col11" >Modularity</th>
#       <th id="T_fe383_level1_col12" class="col_heading level1 col12" >Coverage</th>
#       <th id="T_fe383_level1_col13" class="col_heading level1 col13" >DGE RBO</th>
#       <th id="T_fe383_level1_col14" class="col_heading level1 col14" >DGE Kendall</th>
#       <th id="T_fe383_level1_col15" class="col_heading level1 col15" >DGE Jaccard</th>
#       <th id="T_fe383_level1_col16" class="col_heading level1 col16" >scGraph Corr</th>
#       <th id="T_fe383_level1_col17" class="col_heading level1 col17" >Modularity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe383_level0_row0" class="row_heading level0 row0" >Leiden (ComBat)</th>
#       <td id="T_fe383_row0_col0" class="data row0 col0" >0.93</td>
#       <td id="T_fe383_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_fe383_row0_col2" class="data row0 col2" >-</td>
#       <td id="T_fe383_row0_col3" class="data row0 col3" >-</td>
#       <td id="T_fe383_row0_col4" class="data row0 col4" >-</td>
#       <td id="T_fe383_row0_col5" class="data row0 col5" >0.60</td>
#       <td id="T_fe383_row0_col6" class="data row0 col6" >1.00</td>
#       <td id="T_fe383_row0_col7" class="data row0 col7" >-</td>
#       <td id="T_fe383_row0_col8" class="data row0 col8" >-</td>
#       <td id="T_fe383_row0_col9" class="data row0 col9" >-</td>
#       <td id="T_fe383_row0_col10" class="data row0 col10" >-</td>
#       <td id="T_fe383_row0_col11" class="data row0 col11" >0.73</td>
#       <td id="T_fe383_row0_col12" class="data row0 col12" >1.00</td>
#       <td id="T_fe383_row0_col13" class="data row0 col13" >-</td>
#       <td id="T_fe383_row0_col14" class="data row0 col14" >-</td>
#       <td id="T_fe383_row0_col15" class="data row0 col15" >-</td>
#       <td id="T_fe383_row0_col16" class="data row0 col16" >-</td>
#       <td id="T_fe383_row0_col17" class="data row0 col17" >0.65</td>
#     </tr>
#     <tr>
#       <th id="T_fe383_level0_row1" class="row_heading level0 row1" >Leiden (Harmony)</th>
#       <td id="T_fe383_row1_col0" class="data row1 col0" >0.79</td>
#       <td id="T_fe383_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_fe383_row1_col2" class="data row1 col2" >-</td>
#       <td id="T_fe383_row1_col3" class="data row1 col3" >-</td>
#       <td id="T_fe383_row1_col4" class="data row1 col4" >-</td>
#       <td id="T_fe383_row1_col5" class="data row1 col5" >0.28</td>
#       <td id="T_fe383_row1_col6" class="data row1 col6" >0.82</td>
#       <td id="T_fe383_row1_col7" class="data row1 col7" >-</td>
#       <td id="T_fe383_row1_col8" class="data row1 col8" >-</td>
#       <td id="T_fe383_row1_col9" class="data row1 col9" >-</td>
#       <td id="T_fe383_row1_col10" class="data row1 col10" >-</td>
#       <td id="T_fe383_row1_col11" class="data row1 col11" >0.44</td>
#       <td id="T_fe383_row1_col12" class="data row1 col12" >1.00</td>
#       <td id="T_fe383_row1_col13" class="data row1 col13" >-</td>
#       <td id="T_fe383_row1_col14" class="data row1 col14" >-</td>
#       <td id="T_fe383_row1_col15" class="data row1 col15" >-</td>
#       <td id="T_fe383_row1_col16" class="data row1 col16" >-</td>
#       <td id="T_fe383_row1_col17" class="data row1 col17" >0.28</td>
#     </tr>
#     <tr>
#       <th id="T_fe383_level0_row2" class="row_heading level0 row2" >SEACells (ComBat)</th>
#       <td id="T_fe383_row2_col0" class="data row2 col0" >0.86</td>
#       <td id="T_fe383_row2_col1" class="data row2 col1" >-</td>
#       <td id="T_fe383_row2_col2" class="data row2 col2" >-</td>
#       <td id="T_fe383_row2_col3" class="data row2 col3" >-</td>
#       <td id="T_fe383_row2_col4" class="data row2 col4" >0.84</td>
#       <td id="T_fe383_row2_col5" class="data row2 col5" >0.44</td>
#       <td id="T_fe383_row2_col6" class="data row2 col6" >1.00</td>
#       <td id="T_fe383_row2_col7" class="data row2 col7" >-</td>
#       <td id="T_fe383_row2_col8" class="data row2 col8" >-</td>
#       <td id="T_fe383_row2_col9" class="data row2 col9" >-</td>
#       <td id="T_fe383_row2_col10" class="data row2 col10" >0.87</td>
#       <td id="T_fe383_row2_col11" class="data row2 col11" >0.47</td>
#       <td id="T_fe383_row2_col12" class="data row2 col12" >1.00</td>
#       <td id="T_

# %%
# --- Rare-cell-type table (the key hypothesis test for BOTH of ComBat's structural
# limitations discussed in the intro cell): coverage + homogeneity + F1, same
# per-batch-rare-cell definition results.tex uses for Table 2 (tab:rare_cells).
#
# batch_rare_f1_macro_mean -- per-rare-type F1 (precision = purity of that type's
# dedicated metacell(s), recall = fraction of that type's cells that landed in one),
# macro-averaged across rare types, then mean+-std across batches.
#
# batch_rare_cross_batch_homog_mean -- same formula/denominator as homogeneity, but the
# numerator only counts same-label metacell-mates from a DIFFERENT batch -- directly
# tests whether rare types are actually grouped WITH their cross-batch counterparts,
# not just given their own same-batch-only cluster.
df_rare = rare_celltype_purity_table(RNA_SEQ_DATASETS, model_keywords=MODEL_KEYWORDS, verbose=True)

_dupe_mask = df_rare.index.duplicated(keep='first')
if _dupe_mask.any():
    print(f"WARNING: dropped {_dupe_mask.sum()} duplicate row(s) from df_rare: "
          f"{df_rare.index[_dupe_mask].tolist()}")
    df_rare = df_rare[~_dupe_mask]

show_table(
    df_rare,
    metrics=[
        'batch_rare_coverage_mean', 'batch_rare_recall_macro_mean',
        'batch_rare_precision_macro_mean', 'batch_rare_homogeneity_mean',
        'batch_rare_cross_batch_homog_mean', 'batch_rare_f1_macro_mean',
    ],
    dataset_display_names=dataset_display_names,
)
# Out:
#   [scProto|pancreas] resolving run dir ...
#   [SEACells (PCA)|pancreas] resolving run dir ...
#   [SEACells (ComBat)|pancreas] resolving run dir ...
#   [Leiden (ComBat)|pancreas] resolving run dir ...
#   [SEACells (Harmony)|pancreas] resolving run dir ...
#   [SEACells (PCA)|pancreas] run dir resolved (0.0s)
#   [Leiden (Harmony)|pancreas] resolving run dir ...
#   [scProto|lung] resolving run dir ...
#   [SEACells (PCA)|lung] resolving run dir ...
#   [SEACells (PCA)|lung] run dir resolved (0.0s)
#   [SEACells (PCA)|pancreas] reading umap_cells.csv ...
#   [SEACells (PCA)|lung] reading umap_cells.csv ...
#   [scProto|lung] run dir resolved (0.0s)
#   [scProto|lung] reading umap_cells.csv ...
#   [Leiden (ComBat)|pancreas] run dir resolved (0.0s)  [SEACells (Harmony)|pancreas] run dir resolved (0.0s)
#
#   [scProto|pancreas] run dir resolved (0.0s)
#   [SEACells (ComBat)|pancreas] run dir resolved (0.0s)
#   [Leiden (ComBat)|pancreas] reading umap_cells.csv ...
#   [SEACells (Harmony)|pancreas] reading umap_cells.csv ...
#   [Leiden (Harmony)|pancreas] run dir resolved (0.0s)  [scProto|pancreas] reading umap_cells.csv ...
#   [SEACells (ComBat)|pancreas] reading umap_cells.csv ...
#
#   [Leiden (Harmony)|pancreas] reading umap_cells.csv ...
#   [Leiden (ComBat)|pancreas] umap_cells.csv loaded (16382 rows, 0.0s)
#   [Leiden (ComBat)|pancreas] reading umap_protos.csv ...
#   [Leiden (ComBat)|pancreas] umap_protos.csv loaded (0.0s)
#   [SEACells (ComBat)|pancreas] umap_cells.csv loaded (16382 rows, 0.0s)
#   [Leiden (ComBat)|pancreas] batch='tech' | 9 unique values, e.g. ['celseq', 'celseq2', 'fluidigmc1', 'inDrop1', 'inDrop2']
#   [Leiden (ComBat)|pancreas] label='celltype', batch='tech' | computing metacell label fractions ...  [SEACells (ComBat)|pancreas] reading umap_protos.csv ...
#
#   [SEACells (ComBat)|pancreas] umap_protos.csv loaded (0.0s)
#   [SEACells (ComBat)|pancreas] batch='tech' | 9 unique values, e.g. ['celseq', 'celseq2', 'fluidigmc1', 'inDrop1', 'inDrop2']
#   [SEACells (ComBat)|pancreas] label='celltype', batch='tech' | computing metacell label fractions ...
#   [Leiden (ComBat)|pancreas] label fractions done (0.0s)
#   [SEACells (ComBat)|pancreas] label fractions done (0.0s)
#   [Leiden (ComBat)|pancreas] done
#   [SEACells (ComBat)|lung] resolving run dir ...
#   [Leiden (ComBat)] ds=pancreas: coverage=0.77±0.20  repr macro=0.56±0.17  micro=0.60±0.15  homogeneity=0.60±0.15  cross_batch_homog=0.53±0.16  purity=0.80±0.13  recall=0.71±0.16  precision=0.68±0.18  F1=0.64±0.18
#   [SEACells (ComBat)|lung] run dir resolved (0.0s)
#   [SEACells (ComBat)|lung] reading umap_cells.csv ...
#   [SEACells (ComBat)|pancreas] done
#   [Leiden (ComBat)|lung] resolving run dir ...
#   [SEACells (ComBat)] ds=pancreas: coverage=0.64±0.24  repr macro=0.51±0.20  micro=0.55±0.17  homogeneity=0.55±0.17  cross_batch_homog=0.46±0.14  purity=0.82±0.13  recall=0.58±0.20  precision=0.55±0.23  F1=0.55±0.23
#   [Leiden (ComBat)|lung] run dir resolved (0.0s)
#   [Leiden (ComBat)|lung] reading umap_cells.csv ...
#   [SEACells (ComBat)|lung] umap_cells.csv loaded (32472 rows, 0.0s)
#   [SEACells (ComBat)|lung] reading umap_protos.csv ...
#   [SEACells (ComBat)|lung] umap_protos.csv loaded (0.0s)
#   [SEACells (ComBat)|lung] batch='batch' | 16 unique values, e.g. ['1', '2', '3', '4', '5']
#   [SEACells (ComBat)|lung] label='cell_type', batch='batch' | computing metacell label fractions ...
#   [SEACells (ComBat)|lung] label fractions done (0.0s)  [Leiden (ComBat)|lung] umap_cells.csv loaded (32472 rows, 0.0s)
#
#   [Leiden (ComBat)|lung] reading umap_protos.csv ...
#   [Leiden (ComBat)|lung] umap_protos.csv loaded (0.0s)
#   [Leiden (ComBat)|lung] batch='batch' | 16 unique values, e.g. ['1', '2', '3', '4', '5']
#   [Leiden (ComBat)|lung] label='cell_type', batch='batch' | computing metacell label fractions ...
#   [Leiden (ComBat)|lung] label fractions done (0.0s)
#   [SEACells (ComBat)|lung] done
#   [SEACells (Harmony)|lung] resolving run dir ...
#   [SEACells (ComBat)] ds=lung: coverage=0.69±0.30  repr macro=0.53±0.23  micro=0.54±0.26  homogeneity=0.54±0.26  cross_batch_homog=0.45±0.22  purity=0.87±0.03  recall=0.55±0.24  precision=0.84±0.06  F1=0.55±0.24
#   [SEACells (Harmony)|lung] run dir resolved (0.0s)
#   [SEACells (Harmony)|lung] reading umap_cells.csv ...
#   [Leiden (ComBat)|lung] done
#   [Leiden (Harmony)|lung] resolving run dir ...
#   [Leiden (ComBat)] ds=lung: coverage=0.67±0.32  repr macro=0.51±0.24  micro=0.53±0.27  homogeneity=0.53±0.27  cross_batch_homog=0.45±0.26  purity=0.80±0.10  recall=0.56±0.30  precision=0.78±0.07  F1=0.54±0.27
#   [Leiden (Harmony)|lung] run dir resolved (0.0s)
#   [Leiden (Harmony)|lung] reading umap_cells.csv ...
#   [SEACells (PCA)|pancreas] umap_cells.csv loaded (16382 rows, 0.5s)
#   [SEACells (PCA)|pancreas] reading umap_protos.csv ...
#   [SEACells (PCA)|lung] umap_cells.csv loaded (32472 rows, 0.5s)
#   [SEACells (PCA)|lung] reading umap_protos.csv ...
#   [scProto|pancreas] umap_cells.csv loaded (16382 rows, 0.5s)
#   [scProto|pancreas] reading umap_protos.csv ...
#   [SEACells (Harmony)|pancreas] umap_cells.csv loaded (16382 rows, 0.6s)
#   [SEACells (Harmony)|pancreas] reading umap_protos.csv ...
#   [Leiden (Harmony)|pancreas] umap_cells.csv loaded (16382 rows, 0.7s)
#   [Leiden (Harmony)|pancreas] reading umap_protos.csv ...
#   [SEACells (Harmony)|lung] umap_cells.csv loaded (32472 rows, 0.5s)
#   [SEACells (Harmony)|lung] reading umap_protos.csv ...
#   [scProto|lung] umap_cells.csv loaded (32472 rows, 0.8s)
#   [scProto|lung] reading umap_protos.csv ...
#   [scProto|pancreas] umap_protos.csv loaded (0.4s)
#   [Leiden (Harmony)|lung] umap_cells.csv loaded (32472 rows, 0.7s)
#   [scProto|pancreas] batch='tech' | 9 unique values, e.g. ['celseq', 'celseq2', 'fluidigmc1', 'inDrop1', 'inDrop2']
#   [Leiden (Harmony)|lung] reading umap_protos.csv ...
#   [scProto|pancreas] label='celltype', batch='tech' | computing metacell label fractions ...
#   [scProto|pancreas] label fractions done (0.0s)
#   [SEACells (Harmony)|pancreas] umap_protos.csv loaded (0.4s)
#   [SEACells (Harmony)|pancreas] batch='tech' | 9 unique values, e.g. ['celseq', 'celseq2', 'fluidigmc1', 'inDrop1', 'inDrop2']
#   [SEACells (Harmony)|pancreas] label='celltype', batch='tech' | computing metacell label fractions ...
#   [SEACells (Harmony)|pancreas] label fractions done (0.0s)
#   [scProto|pancreas] done
#   [scProto|pbmc-immune] resolving run dir ...
#   [scProto] ds=pancreas: coverage=0.64±0.24  repr macro=0.53±0.17  micro=0.56±0.16  homogeneity=0.56±0.16  cross_batch_homog=0.32±0.18  purity=0.88±0.08  recall=0.54±0.20  precision=0.77±0.13  F1=0.54±0.21
#   [SEACells (PCA)|lung] umap_protos.csv loaded (0.5s)
#   [SEACells (PCA)|lung] batch='batch' | 16 unique values, e.g. ['1', '2', '3', '4', '5']
#   [SEACells (PCA)|lung] label='cell_type', batch='batch' | computing metacell label fractions ...
#   [SEACells (Harmony)|pancreas] done
#   [SEACells (PCA)|pbmc-immune] resolving run dir ...
#   [SEACells (Harmony)] ds=pancreas: coverage=0.56±0.28  repr macro=0.27±0.12  micro=0.29±0.12  homogeneity=0.29±0.12  cross_batch_homog=0.23±0.10  purity=0.56±0.16  recall=0.35±0.14  precision=0.36±0.18  F1=0.32±0.16
#   [SEACells (PCA)|pbmc-immune] run dir resolved (0.0s)
#   [SEACells (PCA)|pbmc-immune] reading umap_cells.csv ...
#   [SEACells (PCA)|lung] label fractions done (0.0s)
#   [scProto|pbmc-immune] run dir resolved (0.0s)
#   [scProto|pbmc-immune] reading umap_cells.csv ...
#   [SEACells (PCA)|pancreas] umap_protos.csv loaded (0.6s)
#   [SEACells (PCA)|pancreas] batch='tech' | 9 unique values, e.g. ['celseq', 'celseq2', 'fluidigmc1', 'inDrop1', 'inDrop2']
#   [SEACells (PCA)|pancreas] label='celltype', batch='tech' | computing metacell label fractions ...
#   [SEACells (PCA)|lung] done
#   [SEACells (ComBat)|pbmc-immune] resolving run dir ...
#   [SEACells (PCA)] ds=lung: coverage=0.52±0.23  repr macro=0.43±0.19  micro=0.47±0.24  homogeneity=0.47±0.24  cross_batch_homog=0.39±0.20  purity=0.90±0.03  recall=0.41±0.23  precision=0.90±0.04  F1=0.42±0.22
#   [SEACells (ComBat)|pbmc-immune] run dir resolved (0.0s)
#   [SEACells (ComBat)|pbmc-immune] reading umap_cells.csv ...
#   [SEACells (PCA)|pancreas] label fractions done (0.0s)
#   [SEACells (PCA)|pancreas] done
#   [Leiden (ComBat)|pbmc-immune] resolving run dir ...
#   [SEACells (PCA)] ds=pancreas: coverage=0.43±0.27  repr macro=0.39±0.20  micro=0.42±0.20  homogeneity=0.42±0.20  cross_batch_homog=0.22±0.10  purity=0.82±0.13  recall=0.41±0.24  precision=0.54±0.22  F1=0.37±0.25
#   [Leiden (ComBat)|pbmc-immune] run dir resolved (0.0s)
#   [SEACells (ComBat)|pbmc-immune] umap_cells.csv loaded (33506 rows, 0.0s)
#   [Leiden (ComBat)|pbmc-immune] reading umap_cells.csv ...
#   [SEACells (ComBat)|pbmc-immune] reading umap_protos.csv ...
#   [SEACells (ComBat)|pbmc-immune] umap_protos.csv loaded (0.0s)
#   [SEACells (ComBat)|pbmc-immune] batch='study' | 5 unique values, e.g. ['10X', 'Freytag', 'Oetjen', 'Sun', 'Villani']
#   [SEACells (ComBat)|pbmc-immune] label='final_annotation', batch='study' | computing metacell label fractions ...
#   [SEACells (ComBat)|pbmc-immune] label fractions done (0.0s)
#   [Leiden (ComBat)|pbmc-immune] umap_cells.csv loaded (33506 rows, 0.0s)
#   [Leiden (ComBat)|pbmc-immune] reading umap_protos.csv ...
#   [Leiden (ComBat)|pbmc-immune] umap_protos.csv loaded (0.0s)
#   [Leiden (ComBat)|pbmc-immune] batch='study' | 5 unique values, e.g. ['10X', 'Freytag', 'Oetjen', 'Sun', 'Villani']
#   [Leiden (ComBat)|pbmc-immune] label='final_annotation', batch='study' | computing metacell label fractions ...
#   [SEACells (ComBat)|pbmc-immune] done
#   [SEACells (Harmony)|pbmc-immune] resolving run dir ...
#   [SEACells (ComBat)] ds=pbmc-immune: coverage=1.00±0.00  repr macro=0.83±0.11  micro=0.83±0.13  homogeneity=0.83±0.13  cross_batch_homog=0.19±0.12  purity=0.91±0.04  recall=0.94±0.03  precision=0.90±0.03  F1=0.92±0.03
#   [SEACells (Harmony)|pbmc-immune] run dir resolved (0.0s)
#   [SEACells (Harmony)|pbmc-immune] reading umap_cells.csv ...
#   [Leiden (ComBat)|pbmc-immune] label fractions done (0.0s)
#   [Leiden (ComBat)|pbmc-immune] done
#   [Leiden (Harmony)|pbmc-immune] resolving run dir ...
#   [Leiden (ComBat)] ds=pbmc-immune: coverage=1.00±0.00  repr macro=0.77±0.10  micro=0.77±0.11  homogeneity=0.77±0.11  cross_batch_homog=0.42±0.21  purity=0.81±0.15  recall=0.95±0.02  precision=0.81±0.07  F1=0.86±0.06
#   [Leiden (Harmony)|pbmc-immune] run dir resolved (0.0s)
#   [Leiden (Harmony)|pbmc-immune] reading umap_cells.csv ...
#   [Leiden (Harmony)|lung] umap_protos.csv loaded (1.2s)
#   [scProto|lung] umap_protos.csv loaded (1.3s)
#   [SEACells (Harmony)|lung] umap_protos.csv loaded (1.4s)
#   [Leiden (Harmony)|pancreas] umap_protos.csv loaded (1.4s)
#   [Leiden (Harmony)|lung] batch='batch' | 16 unique values, e.g. ['1', '2', '3', '4', '5']
#   [SEACells (Harmony)|lung] batch='batch' | 16 unique values, e.g. ['1', '2', '3', '4', '5']
#   [Leiden (Harmony)|lung] label='cell_type', batch='batch' | computing metacell label fractions ...
#   [scProto|lung] batch='batch' | 16 unique values, e.g. ['1', '2', '3', '4', '5']
#   [SEACells (Harmony)|lung] label='cell_type', batch='batch' | computing metacell label fractions ...
#   [scProto|lung] label='cell_type', batch='batch' | computing metacell label fractions ...
#   [Leiden (Harmony)|pancreas] batch='tech' | 9 unique values, e.g. ['celseq', 'celseq2', 'fluidigmc1', 'inDrop1', 'inDrop2']
#   [Leiden (Harmony)|pancreas] label='celltype', batch='tech' | computing metacell label fractions ...
#   [SEACells (PCA)|pbmc-immune] umap_cells.csv loaded (33506 rows, 1.2s)
#   [SEACells (PCA)|pbmc-immune] reading umap_protos.csv ...
#   [SEACells (Harmony)|pbmc-immune] umap_cells.csv loaded (33506 rows, 1.0s)
#   [SEACells (Harmony)|pbmc-immune] reading umap_protos.csv ...  [Leiden (Harmony)|pbmc-immune] umap_cells.csv loaded (33506 rows, 1.0s)
#
#   [scProto|pbmc-immune] umap_cells.csv loaded (33506 rows, 1.2s)  [Leiden (Harmony)|pbmc-immune] reading umap_protos.csv ...
#
#   [Leiden (Harmony)|pancreas] label fractions done (0.0s)
#   [Leiden (Harmony)|lung] label fractions done (0.0s)
#   [scProto|lung] label fractions done (0.0s)  [scProto|pbmc-immune] reading umap_protos.csv ...
#
#   [SEACells (Harmony)|lung] label fractions done (0.0s)
#   [Leiden (Harmony)|pancreas] done
#   [Leiden (Harmony)] ds=pancreas: coverage=0.40±0.24  repr macro=0.21±0.09  micro=0.22±0.09  homogeneity=0.22±0.09  cross_batch_homog=0.19±0.08  purity=0.52±0.20  recall=0.28±0.19  precision=0.24±0.18  F1=0.22±0.17
#   [scProto|lung] done
#   [scProto] ds=lung: coverage=0.79±0.18  repr macro=0.56±0.20  micro=0.58±0.22  homogeneity=0.58±0.22  cross_batch_homog=0.51±0.20  purity=0.85±0.04  recall=0.60±0.23  precision=0.70±0.14  F1=0.60±0.18
#   [Leiden (Harmony)|lung] done
#   [Leiden (Harmony)] ds=lung: coverage=0.43±0.26  repr macro=0.33±0.10  micro=0.34±0.08  homogeneity=0.34±0.08  cross_batch_homog=0.33±0.09  purity=0.69±0.09  recall=0.31±0.17  precision=0.49±0.13  F1=0.28±0.14
#   [SEACells (Harmony)|lung] done
#   [SEACells (Harmony)] ds=lung: coverage=0.54±0.19  repr macro=0.36±0.10  micro=0.40±0.12  homogeneity=0.40±0.12  cross_batch_homog=0.37±0.12  purity=0.73±0.07  recall=0.38±0.17  precision=0.62±0.11  F1=0.36±0.14
#   [SEACells (PCA)|pbmc-immune] umap_protos.csv loaded (0.5s)
#   [SEACells (PCA)|pbmc-immune] batch='study' | 5 unique values, e.g. ['10X', 'Freytag', 'Oetjen', 'Sun', 'Villani']
#   [SEACells (PCA)|pbmc-immune] label='final_annotation', batch='study' | computing metacell label fractions ...
#   [SEACells (PCA)|pbmc-immune] label fractions done (0.0s)
#   [scProto|pbmc-immune] umap_protos.csv loaded (0.5s)
#   [scProto|pbmc-immune] batch='study' | 5 unique values, e.g. ['10X', 'Freytag', 'Oetjen', 'Sun', 'Villani']
#   [scProto|pbmc-immune] label='final_annotation', batch='study' | computing metacell label fractions ...
#   [scProto|pbmc-immune] label fractions done (0.0s)
#   [SEACells (PCA)|pbmc-immune] done
#   [SEACells (PCA)] ds=pbmc-immune: coverage=1.00±0.00  repr macro=0.84±0.08  micro=0.85±0.07  homogeneity=0.85±0.07  cross_batch_homog=0.12±0.17  purity=0.93±0.03  recall=0.87±0.09  precision=0.94±0.01  F1=0.88±0.08
#   [scProto|pbmc-immune] done
#   [scProto] ds=pbmc-immune: coverage=0.93±0.13  repr macro=0.81±0.11  micro=0.83±0.10  homogeneity=0.83±0.10  cross_batch_homog=0.35±0.20  purity=0.92±0.08  recall=0.88±0.12  precision=0.90±0.03  F1=0.85±0.14
#   [Leiden (Harmony)|pbmc-immune] umap_protos.csv loaded (0.5s)
#   [Leiden (Harmony)|pbmc-immune] batch='study' | 5 unique values, e.g. ['10X', 'Freytag', 'Oetjen', 'Sun', 'Villani']
#   [Leiden (Harmony)|pbmc-immune] label='final_annotation', batch='study' | computing metacell label fractions ...
#   [Leiden (Harmony)|pbmc-immune] label fractions done (0.0s)
#   [Leiden (Harmony)|pbmc-immune] done
#   [Leiden (Harmony)] ds=pbmc-immune: coverage=0.93±0.13  repr macro=0.61±0.11  micro=0.64±0.13  homogeneity=0.64±0.13  cross_batch_homog=0.30±0.18  purity=0.79±0.14  recall=0.80±0.12  precision=0.75±0.15  F1=0.75±0.17
#   [SEACells (Harmony)|pbmc-immune] umap_protos.csv loaded (0.6s)
#   [SEACells (Harmony)|pbmc-immune] batch='study' | 5 unique values, e.g. ['10X', 'Freytag', 'Oetjen', 'Sun', 'Villani']
#   [SEACells (Harmony)|pbmc-immune] label='final_annotation', batch='study' | computing metacell label fractions ...
#   [SEACells (Harmony)|pbmc-immune] label fractions done (0.0s)
#   [SEACells (Harmony)|pbmc-immune] done
#   [SEACells (Harmony)] ds=pbmc-immune: coverage=0.93±0.13  repr macro=0.65±0.17  micro=0.68±0.19  homogeneity=0.68±0.19  cross_batch_homog=0.25±0.15  purity=0.82±0.10  recall=0.77±0.15  precision=0.81±0.08  F1=0.75±0.16
# <style type="text/css">
# #T_7cd3c th.col_heading.level1.col0 {
#   border-left: 2px solid #555;
# }
# #T_7cd3c td.col0 {
#   border-left: 2px solid #555;
# }
# #T_7cd3c th.col_heading.level1.col6 {
#   border-left: 2px solid #555;
# }
# #T_7cd3c td.col6 {
#   border-left: 2px solid #555;
# }
# #T_7cd3c th.col_heading.level1.col12 {
#   border-left: 2px solid #555;
# }
# #T_7cd3c td.col12 {
#   border-left: 2px solid #555;
# }
# #T_7cd3c th.col_heading.level0 {
#   text-align: center;
#   font-weight: bold;
#   border-bottom: 1px solid #aaa;
# }
# #T_7cd3c th.col_heading.level1 {
#   text-align: center;
# }
# #T_7cd3c th.row_heading {
#   text-align: left;
# }
# #T_7cd3c_row0_col0, #T_7cd3c_row0_col1, #T_7cd3c_row0_col3, #T_7cd3c_row0_col4, #T_7cd3c_row0_col5, #T_7cd3c_row0_col12, #T_7cd3c_row0_col13, #T_7cd3c_row0_col16, #T_7cd3c_row2_col12, #T_7cd3c_row2_col17, #T_7cd3c_row4_col8, #T_7cd3c_row4_col12, #T_7cd3c_row4_col14, #T_7cd3c_row4_col15, #T_7cd3c_row5_col2, #T_7cd3c_row5_col6, #T_7cd3c_row5_col7, #T_7cd3c_row5_col9, #T_7cd3c_row5_col10, #T_7cd3c_row5_col11 {
#   font-weight: bold;
# }
# #T_7cd3c_row0_col2, #T_7cd3c_row0_col7, #T_7cd3c_row0_col10, #T_7cd3c_row1_col12, #T_7cd3c_row2_col0, #T_7cd3c_row2_col1, #T_7cd3c_row2_col4, #T_7cd3c_row2_col5, #T_7cd3c_row2_col6, #T_7cd3c_row2_col8, #T_7cd3c_row2_col9, #T_7cd3c_row2_col11, #T_7cd3c_row2_col13, #T_7cd3c_row2_col14, #T_7cd3c_row2_col15, #T_7cd3c_row3_col12, #T_7cd3c_row4_col17, #T_7cd3c_row5_col0, #T_7cd3c_row5_col3, #T_7cd3c_row5_col12, #T_7cd3c_row5_col14, #T_7cd3c_row5_col16 {
#   text-decoration: underline;
# }
# </style>
# <table id="T_7cd3c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th id="T_7cd3c_level0_col0" class="col_heading level0 col0" colspan="6">Pancreas</th>
#       <th id="T_7cd3c_level0_col6" class="col_heading level0 col6" colspan="6">Lung</th>
#       <th id="T_7cd3c_level0_col12" class="col_heading level0 col12" colspan="6">Immune</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Metric</th>
#       <th id="T_7cd3c_level1_col0" class="col_heading level1 col0" >Batch-Rare Coverage</th>
#       <th id="T_7cd3c_level1_col1" class="col_heading level1 col1" >batch_rare_recall_macro_mean</th>
#       <th id="T_7cd3c_level1_col2" class="col_heading level1 col2" >batch_rare_precision_macro_mean</th>
#       <th id="T_7cd3c_level1_col3" class="col_heading level1 col3" >Batch-Rare Homogeneity</th>
#       <th id="T_7cd3c_level1_col4" class="col_heading level1 col4" >Cross-Batch Rare Homogeneity</th>
#       <th id="T_7cd3c_level1_col5" class="col_heading level1 col5" >Batch-Rare F1 (macro)</th>
#       <th id="T_7cd3c_level1_col6" class="col_heading level1 col6" >Batch-Rare Coverage</th>
#       <th id="T_7cd3c_level1_col7" class="col_heading level1 col7" >batch_rare_recall_macro_mean</th>
#       <th id="T_7cd3c_level1_col8" class="col_heading level1 col8" >batch_rare_precision_macro_mean</th>
#       <th id="T_7cd3c_level1_col9" class="col_heading level1 col9" >Batch-Rare Homogeneity</th>
#       <th id="T_7cd3c_level1_col10" class="col_heading level1 col10" >Cross-Batch Rare Homogeneity</th>
#       <th id="T_7cd3c_level1_col11" class="col_heading level1 col11" >Batch-Rare F1 (macro)</th>
#       <th id="T_7cd3c_level1_col12" class="col_heading level1 col12" >Batch-Rare Coverage</th>
#       <th id="T_7cd3c_level1_col13" class="col_heading level1 col13" >batch_rare_recall_macro_mean</th>
#       <th id="T_7cd3c_level1_col14" class="col_heading level1 col14" >batch_rare_precision_macro_mean</th>
#       <th id="T_7cd3c_level1_col15" class="col_heading level1 col15" >Batch-Rare Homogeneity</th>
#       <th id="T_7cd3c_level1_col16" class="col_heading level1 col16" >Cross-Batch Rare Homogeneity</th>
#       <th id="T_7cd3c_level1_col17" class="col_heading level1 col17" >Batch-Rare F1 (macro)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cd3c_level0_row0" class="row_heading level0 row0" >Leiden (ComBat)</th>
#       <td id="T_7cd3c_row0_col0" class="data row0 col0" >0.770 ± 0.200</td>
#       <td id="T_7cd3c_row0_col1" class="data row0 col1" >0.710 ± 0.160</td>
#       <td id="T_7cd3c_row0_col2" class="data row0 col2" >0.680 ± 0.180</td>
#       <td id="T_7cd3c_row0_col3" class="data row0 col3" >0.600 ± 0.150</td>
#       <td id="T_7cd3c_row0_col4" class="data row0 col4" >0.530 ± 0.160</td>
#       <td id="T_7cd3c_row0_col5" class="data row0 col5" >0.640 ± 0.180</td>
#       <td id="T_7cd3c_row0_col6" class="data row0 col6" >0.670 ± 0.320</td>
#       <td id="T_7cd3c_row0_col7" class="data row0 col7" >0.560 ± 0.300</td>
#       <td id="T_7cd3c_row0_col8" class="data row0 col8" >0.780 ± 0.070</td>
#       <td id="T_7cd3c_row0_col9" class="data row0 col9" >0.530 ± 0.270</td>
#       <td id="T_7cd3c_row0_col10" class="data row0 col10" >0.450 ± 0.260</td>
#       <td id="T_7cd3c_row0_col11" class="data row0 col11" >0.540 ± 0.270</td>
#       <td id="T_7cd3c_row0_col12" class="data row0 col12" >1.000 ± 0.000</td>
#       <td id="T_7cd3c_row0_col13" class="data row0 col13" >0.950 ± 0.020</td>
#       <td id="T_7cd3c_row0_col14" class="data row0 col14" >0.810 ± 0.070</td>
#       <td id="T_7cd3c_row0_col15" class="data row0 col15" >0.770 ± 0.110</td>
#       <td id="T_7cd3c_row0_col16" class="data row0 col16" >0.420 ± 0.210</td>
#       <td id="T_7cd3c_row0_col17" class="data row0 col17" >0.860 ± 0.060</td>
#     </tr>
#     <tr>
#       <th id="T_7cd3c_level0_row1" class="row_heading level0 row1" >Leiden (Harmony)</th>
#       <td id="T_7cd3c_row1_col0" class="data row1 col0" >0.400 ± 0.240</td>
#       <td id="T_7cd3c_row1_col1" class="data row1 col1" >0.280 ± 0.190</td>
#       <td id="T_7cd3c_row1_col2" class="data row1 col2" >0.240 ± 0.180</td>
#       <td id="T_7cd3c_row1_col3" class="data row1 col3" >0.220 ± 0.090</td>
#       <td id="T_7cd3c_row1_col4" class="data row1 col4" >0.190 ± 0.080</td>
#       <td id="T_7cd3c_row1_col5" class="data row1 col5" >0.220 ± 0.170</td>
#       <td id="T_7cd3c_row1_col6" class="data row1 col6" >0.430 ± 0.260</td>
#       <td id="T_7cd3c_row1_col7" class="data row1 col7" >0.310 ± 0.170</td>
#       <td id="T_7cd3c_row1_col8" class="data row1 col8" >0.490 ± 0.130</td>
#       <td id="T_7cd3c_row1_col9" class="data row1 col9" >0.340 ± 0.080</td>
#       <td id="T_7cd3c_row1_col10" class="data row1 col10" >0.330 ± 0.090</td>
#       <td id="T_7cd3c_row1_col11" class="data row1 col11" >0.280 ± 0.140</td>
#       <td id="T_7cd3c_row1_col12" class="data row1 col12" >0.930 ± 0.130</td>
#       <td id="T_7cd3c_row1_col13" class="data row1 col13" >0.800 ± 0.120</td>
#       <td id="T_7cd3c_row1_col14" class="data row1 col14" >0.750 ± 0.150</td>
#       <td id="T_7cd3c_row1_col15" class="data row1 col15" >0.640 ± 0.130</td>
#       <td id="T_7cd3c_row1_col16" class="data row1 col16" >0.300 ± 0.180</td>
#       <td id="T_7cd3c_row1_col17" class="data row1 col17" >0.750 ± 0.170</td>
#     </tr>
#     <tr>
#       <th id="T_7cd3c_level0_row2" class="row_heading level0 row2" >SEACells (ComBat)</th>
#       <td id="T_7cd3c_row2_col0" class="data row2 col0" >0.640 ± 0.240</td>
#       <td id="T_7cd3c_row2_col1" class="data row2 col1" >0.580 ± 0.200</td>
#       <td id="T_7cd3c_row2_col2" class="data row2 col2" >0.550 ± 0.230</td>
#       <td id="T_7cd3c_row2_col3" class="

# %%
# --- PAIRED significance test for the rare-cell table above (Wilcoxon signed-rank,
# scProto vs. each same-K baseline, Bonferroni-corrected per dataset) -- same
# convention used throughout the Harmony notebook and results.tex.
from interpretable_ssl.evaluation.paper_figures import rare_metric_significance_paired

df_sig_paired = rare_metric_significance_paired(
    df_rare,
    ref_name='scProto',
    metrics=(
        '_batch_rare_f1_macro_per_batch',
        '_batch_rare_homogeneity_per_batch',
        '_batch_rare_cross_batch_homog_per_batch',
    ),
    dataset_display_names=dataset_display_names,
)
df_sig_paired
# Out:
#      dataset                        metric              method    k   n  \
# 0   Pancreas           batch_rare_f1_macro             scProto  219   8
# 1   Pancreas           batch_rare_f1_macro      SEACells (PCA)  220   8
# 2   Pancreas           batch_rare_f1_macro   SEACells (ComBat)  220   8
# 3   Pancreas           batch_rare_f1_macro     Leiden (ComBat)  220   8
# 4   Pancreas           batch_rare_f1_macro  SEACells (Harmony)  220   8
# 5   Pancreas           batch_rare_f1_macro    Leiden (Harmony)  220   8
# 6   Pancreas        batch_rare_homogeneity             scProto  219   8
# 7   Pancreas        batch_rare_homogeneity      SEACells (PCA)  220   8
# 8   Pancreas        batch_rare_homogeneity   SEACells (ComBat)  220   8
# 9   Pancreas        batch_rare_homogeneity     Leiden (ComBat)  220   8
# 10  Pancreas        batch_rare_homogeneity  SEACells (Harmony)  220   8
# 11  Pancreas        batch_rare_homogeneity    Leiden (Harmony)  220   8
# 12  Pancreas  batch_rare_cross_batch_homog             scProto  219   8
# 13  Pancreas  batch_rare_cross_batch_homog      SEACells (PCA)  220   8
# 14  Pancreas  batch_rare_cross_batch_homog   SEACells (ComBat)  220   8
# 15  Pancreas  batch_rare_cross_batch_homog     Leiden (ComBat)  220   8
# 16  Pancreas  batch_rare_cross_batch_homog  SEACells (Harmony)  220   8
# 17  Pancreas  batch_rare_cross_batch_homog    Leiden (Harmony)  220   8
# 18      Lung           batch_rare_f1_macro             scProto  298  15
# 19      Lung           batch_rare_f1_macro      SEACells (PCA)  300  15
# 20      Lung           batch_rare_f1_macro   SEACells (ComBat)  300  15
# 21      Lung           batch_rare_f1_macro     Leiden (ComBat)  300  15
# 22      Lung           batch_rare_f1_macro  SEACells (Harmony)  300  15
# 23      Lung           batch_rare_f1_macro    Leiden (Harmony)  300  15
# 24      Lung        batch_rare_homogeneity             scProto  298  15
# 25      Lung        batch_rare_homogeneity      SEACells (PCA)  300  15
# 26      Lung        batch_rare_homogeneity   SEACells (ComBat)  300  15
# 27      Lung        batch_rare_homogeneity     Leiden (ComBat)  300  15
# 28      Lung        batch_rare_homogeneity  SEACells (Harmony)  300  15
# 29      Lung        batch_rare_homogeneity    Leiden (Harmony)  300  15
# 30      Lung  batch_rare_cross_batch_homog             scProto  298  15
# 31      Lung  batch_rare_cross_batch_homog      SEACells (PCA)  300  15
# 32      Lung  batch_rare_cross_batch_homog   SEACells (ComBat)  300  15
# 33      Lung  batch_rare_cross_batch_homog     Leiden (ComBat)  300  15
# 34      Lung  batch_rare_cross_batch_homog  SEACells (Harmony)  300  15
# 35      Lung  batch_rare_cross_batch_homog    Leiden (Harmony)  300  15
# 36    Immune           batch_rare_f1_macro             scProto  294   5
# 37    Immune           batch_rare_f1_macro      SEACells (PCA)  300   5
# 38    Immune           batch_rare_f1_macro   SEACells (ComBat)  300   5
# 39    Immune           batch_rare_f1_macro     Leiden (ComBat)  300   5
# 40    Immune           batch_rare_f1_macro  SEACells (Harmony)  300   5
# 41    Immune           batch_rare_f1_macro    Leiden (Harmony)  300   5
# 42    Immune        batch_rare_homogeneity             scProto  294   5
# 43    Immune        batch_rare_homogeneity      SEACells (PCA)  300   5
# 44    Immune        batch_rare_homogeneity   SEACells (ComBat)  300   5
# 45    Immune        batch_rare_homogeneity     Leiden (ComBat)  300   5
# 46    Immune        batch_rare_homogeneity  SEACells (Harmony)  300   5
# 47    Immune        batch_rare_homogeneity    Leiden (Harmony)  300   5
# 48    Immune  batch_rare_cross_batch_homog             scProto  294   5
# 49    Immune  batch_rare_cross_batch_homog      SEACells (PCA)  300   5
# 50    Immune  batch_rare_cross_batch_homog   SEACells (ComBat)  300   5
# 51    Immune  batch_rare_cross_batch_homog     Leiden (ComBat)  300   5
# 52    Immune  batch_rare_cross_batch_homog  SEACells (Harmony)  300   5
# 53    Immune  batch_rare_cross_batch_homog    Leiden (Harmony)  300   5
#
#       median      mean       std  n_wins  p_vs_ref     p_adj  sig
# 0   0.437680  0.535403  0.207961     NaN       NaN       NaN  NaN
# 1   0.372628  0.370589  0.250869     6.0  0.039062  0.195312   ns
# 2   0.473580  0.546844  0.226098     6.0  0.371094  1.000000   ns
# 3   0.597904  0.640173  0.184677     3.0  0.925781  1.000000   ns
# 4   0.295521  0.316501  0.159421     7.0  0.011719  0.058594   ns
# 5   0.133361  0.223580  0.171156     8.0  0.003906  0.019531    *
# 6   0.522129  0.564854  0.155263     NaN       NaN       NaN  NaN
# 7   0.369265  0.420592  0.195138     8.0  0.003906  0.019531    *
# 8   0.503420  0.550131  0.169192     5.0  0.421875  1.000000   ns
# 9   0.571599  0.603877  0.150869     4.0  0.769531  1.000000   ns
# 10  0.269034  0.285358  0.115015     8.0  0.003906  0.019531    *
# 11  0.220189  0.218359  0.085397     8.0  0.003906  0.019531    *
# 12  0.259411  0.322859  0.179414     NaN       NaN       NaN  NaN
# 13  0.212005  0.221772  0.100594     5.0  0.125000  0.625000   ns
# 14  0.415859  0.462400  0.143728     3.0  0.925781  1.000000   ns
# 15  0.485304  0.533137  0.164728     1.0  0.992188  1.000000   ns
# 16  0.210341  0.227762  0.098150     6.0  0.074219  0.371094   ns
# 17  0.183894  0.188323  0.084876     6.0  0.039062  0.195312   ns
# 18  0.610777  0.599348  0.175935     NaN       NaN       NaN  NaN
# 19  0.498294  0.420330  0.217382    11.0  0.001678  0.008392   **
# 20  0.608028  0.548208  0.243698     6.0  0.380768  1.000000   ns
# 21  0.582746  0.539195  0.273854     8.0  0.244354  1.000000   ns
# 22  0.348333  0.357564  0.144189    13.0  0.000763  0.003815   **
# 23  0.282094  0.280384  0.141206    13.0  0.000305  0.001526   **
# 24  0.586120  0.577994  0.220956     NaN       NaN       NaN  NaN
# 25  0.495372  0.472356  0.242324    13.0  0.002686  0.013428    *
# 26  0.564222  0.537330  0.255286     8.0  0.194702  0.973511   ns
# 27  0.537567  0.525746  0.265270     8.0  0.179565  0.897827   ns
# 28  0.408222  0.402522  0.115704    14.0  0.002136  0.010681    *
# 29  0.344610  0.344719  0.084300    13.0  0.000763  0.003815   **
# 30  0.509701  0.508327  0.196956     NaN       NaN       NaN  NaN
# 31  0.415586  0.393655  0.201346    12.0  0.001678  0.008392   **
# 32  0.531203  0.450000  0.222456     9.0  0.114655  0.573273   ns
# 33  0.471999  0.453982  0.263483    11.0  0.126190  0.630951   ns
# 34  0.398968  0.371869  0.121918    14.0  0.003357  0.016785    *
# 35  0.341005  0.328868  0.089351    13.0  0.003357  0.016785    *
# 36  0.896681  0.854140  0.138252     NaN       NaN       NaN  NaN
# 37  0.922877  0.879883  0.082663     2.0  0.687500  1.000000   ns
# 38  0.913589  0.918453  0.027815     2.0  0.781250  1.000000   ns
# 39  0.868862  0.857536  0.058015     3.0  0.406250  1.000000   ns
# 40  0.812234  0.750774  0.162481     4.0  0.062500  0.312500   ns
# 41  0.765805  0.751472  0.166212     4.0  0.062500  0.312500   ns
# 42  0.855792  0.827192  0.101982     NaN       NaN       NaN  NaN
# 43  0.815416  0.854752  0.073552     3.0  0.687500  1.000000   ns
# 44  0.857091  0.828798  0.126552     3.0  0.593750  1.000000   ns
# 45  0.792880  0.774417  0.110088     4.0  0.062500  0.312500   ns
# 46  0.804136  0.676898  0.185473     5.0  0.031250  0.156250   ns
# 47  0.706627  0.635473  0.125110     5.0  0.031250  0.156250   ns
# 48  0.406766  0.349204  0.197947     NaN       NaN       NaN  NaN
# 49  0.028607  0.120662  0.166976     3.0  0.072064  0.360318   ns
# 50  0.183074  0.189908  0.116949     4.0  0.062500  0.312500   ns
# 51  0.502932  0.418730  0.214942     1.0  0.906250  1.000000   ns
# 52  0.304594  0.245410  0.153361     3.0  0.156250  0.781250   ns
# 53  0.372796  0.304595  0.181786     2.0  0.232604  1.000000   ns

# %%
# --- PAIRED significance test for Table 1's modularity (scProto vs. each same-K
# baseline). Only modularity_per_batch is pairable (batch is a shared,
# method-independent unit) -- purity_per_mc / batch_entropy_per_mc stay unpaired
# (no natural cross-method correspondence between metacells from different methods).
from interpretable_ssl.evaluation.paper_figures import graph_batch_significance_paired

sig_df_table1_paired = graph_batch_significance_paired(
    RNA_SEQ_DATASETS,
    MODEL_KEYWORDS,
    ref_name='scProto',
    dataset_display_names=dataset_display_names,
)

sub = sig_df_table1_paired.copy()
sub['cell'] = sub.apply(
    lambda r: f"{r['median']:.3f} (K={r['k']}, n={r['n']}) [ref]" if r['method'] == 'scProto'
    else f"{r['median']:.3f} (K={r['k']}, n={r['n']}, wins={r.get('n_wins', '?')}/{r['n']})  "
         f"{r.get('sig', '?')}  p_adj={r.get('p_adj', float('nan')):.3g}",
    axis=1,
)
display(sub.pivot(index='method', columns='dataset', values='cell'))

sig_df_table1_paired
# Out:
# dataset                                                      Immune  \
# method
# Leiden (ComBat)         0.644 (K=300, n=5, wins=3.0/5)  ns  p_adj=1
# Leiden (Harmony)    0.250 (K=300, n=5, wins=5.0/5)  ns  p_adj=0.156
# SEACells (ComBat)   0.414 (K=300, n=5, wins=5.0/5)  ns  p_adj=0.156
# SEACells (Harmony)  0.551 (K=300, n=5, wins=5.0/5)  ns  p_adj=0.156
# SEACells (PCA)      0.569 (K=300, n=5, wins=5.0/5)  ns  p_adj=0.156
# scProto                                    0.620 (K=294, n=5) [ref]
#
# dataset                                                          Lung  \
# method
# Leiden (ComBat)     0.547 (K=300, n=16, wins=14.0/16)  **  p_adj=0...
# Leiden (Harmony)    0.403 (K=300, n=16, wins=16.0/16)  ***  p_adj=...
# SEACells (ComBat)   0.524 (K=300, n=16, wins=16.0/16)  ***  p_adj=...
# SEACells (Harmony)  0.625 (K=300, n=16, wins=14.0/16)  **  p_adj=0...
# SEACells (PCA)          0.671 (K=300, n=16, wins=9.0/16)  ns  p_adj=1
# scProto                                     0.669 (K=298, n=16) [ref]
#
# dataset                                                      Pancreas
# method
# Leiden (ComBat)      0.555 (K=220, n=9, wins=7.0/9)  ns  p_adj=0.0977
# Leiden (Harmony)          0.614 (K=220, n=9, wins=6.0/9)  ns  p_adj=1
# SEACells (ComBat)   0.460 (K=220, n=9, wins=9.0/9)  **  p_adj=0.00977
# SEACells (Harmony)    0.566 (K=220, n=9, wins=7.0/9)  ns  p_adj=0.625
# SEACells (PCA)            0.658 (K=220, n=9, wins=0.0/9)  ns  p_adj=1
# scProto                                      0.621 (K=219, n=9) [ref]
#      dataset                metric              method    k   n    median  \
# 0   Pancreas  modularity_per_batch             scProto  219   9  0.621456
# 1   Pancreas  modularity_per_batch      SEACells (PCA)  220   9  0.657892
# 2   Pancreas  modularity_per_batch   SEACells (ComBat)  220   9  0.460322
# 3   Pancreas  modularity_per_batch     Leiden (ComBat)  220   9  0.555147
# 4   Pancreas  modularity_per_batch  SEACells (Harmony)  220   9  0.566367
# 5   Pancreas  modularity_per_batch    Leiden (Harmony)  220   9  0.614318
# 6       Lung  modularity_per_batch             scProto  298  16  0.669390
# 7       Lung  modularity_per_batch      SEACells (PCA)  300  16  0.671340
# 8       Lung  modularity_per_batch   SEACells (ComBat)  300  16  0.523828
# 9       Lung  modularity_per_batch     Leiden (ComBat)  300  16  0.547357
# 10      Lung  modularity_per_batch  SEACells (Harmony)  300  16  0.624808
# 11      Lung  modularity_per_batch    Leiden (Harmony)  300  16  0.403452
# 12    Immune  modularity_per_batch             scProto  294   5  0.619596
# 13    Immune  modularity_per_batch      SEACells (PCA)  300   5  0.568733
# 14    Immune  modularity_per_batch   SEACells (ComBat)  300   5  0.413688
# 15    Immune  modularity_per_batch     Leiden (ComBat)  300   5  0.644047
# 16    Immune  modularity_per_batch  SEACells (Harmony)  300   5  0.551127
# 17    Immune  modularity_per_batch    Leiden (Harmony)  300   5  0.250021
#
#         mean       std  n_wins  p_vs_ref     p_adj  sig
# 0   0.601234  0.083385     NaN       NaN       NaN  NaN
# 1   0.673906  0.050910     0.0  1.000000  1.000000   ns
# 2   0.460131  0.064516     9.0  0.001953  0.009766   **
# 3   0.533242  0.143306     7.0  0.019531  0.097656   ns
# 4   0.567150  0.017709     7.0  0.125000  0.625000   ns
# 5   0.612469  0.021231     6.0  0.544922  1.000000   ns
# 6   0.664444  0.022871     NaN       NaN       NaN  NaN
# 7   0.673784  0.037789     9.0  0.628220  1.000000   ns
# 8   0.523220  0.028749    16.0  0.000015  0.000076  ***
# 9   0.553988  0.075268    14.0  0.000381  0.001907   **
# 10  0.606050  0.044595    14.0  0.000214  0.001068   **
# 11  0.419322  0.146812    16.0  0.000015  0.000076  ***
# 12  0.628591  0.051655     NaN       NaN       NaN  NaN
# 13  0.553930  0.031290     5.0  0.031250  0.156250   ns
# 14  0.429162  0.064090     5.0  0.031250  0.156250   ns
# 15  0.575565  0.148771     3.0  0.218750  1.000000   ns
# 16  0.548892  0.012923     5.0  0.031250  0.156250   ns
# 17  0.296661  0.109232     5.0  0.031250  0.156250   ns

# %% [markdown]
# ### Realized cluster/metacell count vs. scProto's target K
#
# Sanity check that ComBat's downstream SEACells/Leiden actually landed at (approximately)
# scProto's own `num_prototypes` for each dataset, per the paper's own protocol ("All
# baselines are configured to produce the same number of metacells K as scProto"). Reads
# directly from each run's saved outputs -- no recompute.

# %%
target_k = {ds: DATASETS[ds]['num_prototypes'] for ds in RNA_SEQ_DATASETS}

# Leiden: reads n_clusters/resolution straight from metrics.json
df_combat_k = load_task1_multi(RNA_SEQ_DATASETS, metrics=['n_clusters', 'resolution'])
if df_combat_k.empty:
    print("No runs found yet under MODEL_DIR for RNA_SEQ_DATASETS -- run the 'Run: ...' "
          "cells above first.")
else:
    is_combat_leiden = df_combat_k.index.get_level_values('run').str.startswith('leiden_X_combat')
    df_combat_k_leiden = df_combat_k[is_combat_leiden].copy()
    if df_combat_k_leiden.empty:
        print("No leiden_X_combat run found yet for any dataset in RNA_SEQ_DATASETS.")
    else:
        df_combat_k_leiden['target_k'] = [target_k[ds] for ds, _run in df_combat_k_leiden.index]
        df_combat_k_leiden['matches_target'] = df_combat_k_leiden['n_clusters'] == df_combat_k_leiden['target_k']
        display(df_combat_k_leiden)

# SEACells: no K in the folder name -- read realized count from cell_assignments.csv directly
from interpretable_ssl.evaluation.batch_correct_baselines import get_realized_seacell_count

seacell_k_rows = []
for ds_id in RNA_SEQ_DATASETS:
    n_actual = get_realized_seacell_count(ds_id, 'X_combat')
    k = target_k[ds_id]
    seacell_k_rows.append({
        'dataset': ds_id, 'method': 'combat',
        'n_actual': n_actual, 'target_k': k,
        'matches_target': (n_actual is not None and abs(n_actual - k) <= 0.05 * k),
    })

df_seacell_k = pd.DataFrame(seacell_k_rows).set_index(['dataset', 'method'])
if df_seacell_k['n_actual'].isna().all():
    print("No seacell_X_combat runs found on disk yet for RNA_SEQ_DATASETS.")
else:
    display(df_seacell_k)
# Out:
#                                  n_clusters resolution  target_k  \
# dataset     run
# pancreas    leiden_X_combat_K220      220.0       32.0       220
# lung        leiden_X_combat_K300      300.0       64.0       300
# pbmc-immune leiden_X_combat_K300      300.0       32.0       300
#
#                                   matches_target
# dataset     run
# pancreas    leiden_X_combat_K220            True
# lung        leiden_X_combat_K300            True
# pbmc-immune leiden_X_combat_K300            True
#                     n_actual  target_k  matches_target
# dataset     method
# pancreas    combat       220       220            True
# lung        combat       300       300            True
# pbmc-immune combat       300       300            True

# %% [markdown]
# ## Embedding-only rare-cell affinity purity (no downstream clustering)
#
# Isolates the embedding from whichever clustering algorithm runs on top of it -- for each
# method's raw embedding, builds one ARBF affinity graph directly on it, then for each
# locally-rare-type cell scores what fraction of its total affinity MASS goes to
# same-type cells. This is the most direct empirical check of ComBat's structural
# limitation #2 from the intro cell (one shift per gene per batch, not per cell type): if
# that blunt correction is distorting rare states, it should show up here even before any
# clustering algorithm gets a chance to compensate.
#
# **No separate step to run here** -- this runs automatically at the end of
# `run_all_baselines_for_dataset` (via `compute_and_save_embedding_affinity_purity`), so it
# already ran as part of the `Run: Pancreas` / `Run: Lung` / `Run: PBMC (Immune)` cells
# above. The cell below just loads and displays those saved results.

# %%
from interpretable_ssl.evaluation.batch_correct_baselines import load_and_compare_affinity_purity

df_affinity_purity = load_and_compare_affinity_purity(
    RNA_SEQ_DATASETS, dataset_display_names=dataset_display_names,
)
df_affinity_purity
# Out:
#      dataset                 method  dim   n   mean    std  n_wins  p_vs_ref  \
# 0   Pancreas  Raw PCA (uncorrected)   50   8  0.385  0.164     7.0    0.0742
# 1   Pancreas       scPoli (Stage-1)    8   8  0.512  0.162     3.0    0.8750
# 2   Pancreas                   scVI    8   8  0.365  0.175     8.0    0.0039
# 3   Pancreas                Harmony    8   8  0.297  0.129     7.0    0.0195
# 4   Pancreas                scProto    8   8  0.454  0.184     NaN       NaN
# 5       Lung  Raw PCA (uncorrected)   50  15  0.559  0.194    11.0    0.0240
# 6       Lung       scPoli (Stage-1)    8  15  0.550  0.149    11.0    0.0473
# 7       Lung                scProto    8  15  0.586  0.208     NaN       NaN
# 8     Immune  Raw PCA (uncorrected)   50   5  0.827  0.050     4.0    0.3125
# 9     Immune       scPoli (Stage-1)    8   5  0.841  0.074     2.0    0.4062
# 10    Immune                 ComBat   50   5  0.855  0.067     3.0    0.5938
# 11    Immune                scProto    8   5  0.849  0.085     NaN       NaN
#
#      p_adj  sig
# 0   0.2969   ns
# 1   1.0000   ns
# 2   0.0156    *
# 3   0.0781   ns
# 4      NaN  NaN
# 5   0.0479    *
# 6   0.0946   ns
# 7      NaN  NaN
# 8   0.9375   ns
# 9   1.0000   ns
# 10  1.0000   ns
# 11     NaN  NaN

# %% [markdown]
# ## Targeted per-cell-type breakdown (combat-notes hypotheses)
#
# The tables above macro-average rare-cell metrics across every locally-rare type
# within a batch, then across batches -- which can mask exactly the kind of
# per-type unevenness the two `baseline-notes/combat-notes.md` hypotheses predict.
# This section checks both directly, targeting specific real cell types identified
# empirically from the raw h5ad files (not synthetic/designed cases):
#
# **Hypothesis 1 (ComBat confounds batch artifact with real rare biology confined to
# one batch):** sharpest where a rare type lives almost entirely in ONE batch --
# **Lung's `Neutrophils_IL1R2`** (472 cells, 6/16 batches, 93% concentrated in a
# single batch) is the strongest case across all three datasets; Pancreas has no
# comparably sharp case (its rare types spread across 8-9/9 batches).
#
# **Hypothesis 2 (ComBat's one-shift-per-gene-per-batch can't fit every cell type
# evenly):** the signature isn't the mean across rare types -- it's the SPREAD
# (a method scoring great on one type and terrible on another can still average out
# to look identical to a uniformly-mediocre method). Reported per type below, plus
# a spread (std/min/max) summary across each dataset's bottom-quartile-frequency
# rare types.
#
# Reads already-saved `umap_cells.csv` per run -- no recompute, no retraining.

# %%
# !ls -la /content/drive/MyDrive/codes/interpretable-prototype/interpretable_ssl/evaluation/ | grep rebuttal
# Out:
# -rw------- 1 root root  18683 Jul 30 14:32 rebuttal_report.py

# %%
from interpretable_ssl.evaluation.rebuttal_report import per_celltype_breakdown
import os
# Bottom-quartile-global-frequency rare types per dataset, identified directly from
# the raw h5ad files (obs['celltype']/['cell_type']/['final_annotation'] vs.
# obs['tech']/['batch']) -- see chat history for the per-batch concentration check
# that surfaced Neutrophils_IL1R2 as the sharpest hypothesis-1 case.
RARE_TYPES_BY_DATASET = {
    'pancreas': ['mast', 'epsilon', 'schwann', 't_cell'],
    'lung': ['Neutrophils_IL1R2', 'Type 1', 'Lymphatic', 'Ionocytes'],
    'pbmc-immune': ['Monocyte progenitors', 'Megakaryocyte progenitors', 'CD10+ B cells', 'Plasma cells'],
}

df_celltype_breakdown = pd.concat([
    per_celltype_breakdown(ds_id, MODEL_KEYWORDS, cell_types=cts)
    for ds_id, cts in RARE_TYPES_BY_DATASET.items()
], ignore_index=True)

df_celltype_breakdown
# Out:
#         dataset              method                  cell_type  n_cells  \
# 0      pancreas             scProto                       mast       42
# 1      pancreas             scProto                    epsilon       32
# 2      pancreas             scProto                    schwann       25
# 3      pancreas             scProto                     t_cell        7
# 4      pancreas      SEACells (PCA)                       mast       42
# ..          ...                 ...                        ...      ...
# 67  pbmc-immune  SEACells (Harmony)               Plasma cells      129
# 68  pbmc-immune    Leiden (Harmony)       Monocyte progenitors      428
# 69  pbmc-immune    Leiden (Harmony)  Megakaryocyte progenitors      270
# 70  pbmc-immune    Leiden (Harmony)              CD10+ B cells      207
# 71  pbmc-immune    Leiden (Harmony)               Plasma cells      129
#
#     homogeneity  precision  recall     f1
# 0         0.695      0.798   0.833  0.815
# 1         0.281      0.938   0.281  0.433
# 2         0.628      0.791   0.720  0.754
# 3         0.212      0.000   0.000  0.000
# 4         0.660      0.790   0.881  0.833
# ..          ...        ...     ...    ...
# 67        0.489      0.923   0.473  0.625
# 68        0.314      0.422   0.315  0.361
# 69        0.305      0.596   0.367  0.454
# 70        0.629      0.736   0.758  0.747
# 71        0.252      0.440   0.310  0.364
#
# [72 rows x 8 columns]

# %%
# --- Hypothesis 1, headline case: Lung's Neutrophils_IL1R2 (93% in one batch) ---
# Does ComBat preserve it as a distinct metacell as well as scProto does, or does
# batch-correcting toward the cross-batch typical mean blur this batch-confined
# rare type's identity more than scProto's within-batch-affinity approach does?
df_celltype_breakdown[
    (df_celltype_breakdown['dataset'] == 'lung')
    & (df_celltype_breakdown['cell_type'] == 'Neutrophils_IL1R2')
].sort_values('f1', ascending=False)
# Out:
#    dataset              method          cell_type  n_cells  homogeneity  \
# 28    lung      SEACells (PCA)  Neutrophils_IL1R2      472        0.736
# 32    lung   SEACells (ComBat)  Neutrophils_IL1R2      472        0.453
# 36    lung     Leiden (ComBat)  Neutrophils_IL1R2      472        0.207
# 24    lung             scProto  Neutrophils_IL1R2      472        0.168
# 40    lung  SEACells (Harmony)  Neutrophils_IL1R2      472        0.140
# 44    lung    Leiden (Harmony)  Neutrophils_IL1R2      472        0.143
#
#     precision  recall     f1
# 28      0.800   0.852  0.825
# 32      0.569   0.691  0.624
# 36      0.507   0.180  0.266
# 24      0.000   0.000  0.000
# 40      0.000   0.000  0.000
# 44      0.000   0.000  0.000

# %%
# --- Hypothesis 2: spread (not mean) across each dataset's rare types, per method ---
# High spread (max-min, or std) = uneven across cell types (predicted for ComBat's
# single global per-gene-per-batch shift); low spread = more uniform (predicted
# for scProto, which has no single global correction step).
df_spread = (
    df_celltype_breakdown
    .groupby(['dataset', 'method'])[['homogeneity', 'f1']]
    .agg(['mean', 'std', 'min', 'max'])
)
df_spread['homogeneity_range'] = df_spread[('homogeneity', 'max')] - df_spread[('homogeneity', 'min')]
df_spread['f1_range'] = df_spread[('f1', 'max')] - df_spread[('f1', 'min')]
df_spread
# Out:
#                                homogeneity                               f1  \
#                                       mean       std    min    max     mean
# dataset     method
# lung        Leiden (ComBat)        0.58700  0.311044  0.207  0.968  0.68925
#             Leiden (Harmony)       0.16150  0.104825  0.032  0.285  0.18025
#             SEACells (ComBat)      0.72350  0.220842  0.453  0.966  0.80025
#             SEACells (Harmony)     0.33325  0.134043  0.140  0.450  0.40525
#             SEACells (PCA)         0.80700  0.080440  0.736  0.918  0.88125
#             scProto                0.48075  0.415953  0.093  0.944  0.45025
# pancreas    Leiden (ComBat)        0.46000  0.238849  0.117  0.659  0.56075
#             Leiden (Harmony)       0.11775  0.096834  0.027  0.253  0.11375
#             SEACells (ComBat)      0.37350  0.345038  0.044  0.747  0.40225
#             SEACells (Harmony)     0.16275  0.119970  0.046  0.318  0.22000
#             SEACells (PCA)         0.32150  0.268105  0.045  0.660  0.34950
#             scProto                0.45400  0.242796  0.212  0.695  0.50050
# pbmc-immune Leiden (ComBat)        0.60900  0.335576  0.257  0.917  0.61675
#             Leiden (Harmony)       0.37500  0.171528  0.252  0.629  0.48150
#             SEACells (ComBat)      0.77925  0.105727  0.686  0.881  0.85050
#             SEACells (Harmony)     0.48400  0.100336  0.384  0.620  0.63075
#             SEACells (PCA)         0.79450  0.113621  0.682  0.913  0.85900
#             scProto                0.64325  0.234574  0.350  0.842  0.76225
#
#                                                        homogeneity_range  \
#                                      std    min    max
# dataset     method
# lung        Leiden (ComBat)     0.302923  0.266  0.984             0.761
#             Leiden (Harmony)    0.250855  0.000  0.532             0.253
#             SEACells (ComBat)   0.147902  0.624  0.980             0.513
#             SEACells (Harmony)  0.271393  0.000  0.576             0.310
#             SEACells (PCA)      0.055271  0.825  0.956             0.182
#             scProto             0.523081  0.000  0.971             0.851
# pancreas    Leiden (ComBat)     0.376150  0.000  0.800             0.542
#             Leiden (Harmony)    0.227500  0.000  0.455             0.226
#             SEACells (ComBat)   0.466452  0.000  0.857             0.703
#             SEACells (Harmony)  0.257832  0.000  0.494             0.272
#             SEACells (PCA)      0.418136  0.000  0.833             0.615
#             scProto             0.373376  0.000  0.815             0.483
# pbmc-immune Leiden (ComBat)     0.286574  0.302  0.958             0.660
#             Leiden (Harmony)    0.182184  0.361  0.747             0.377
#             SEACells (ComBat)   0.062233  0.795  0.913             0.195
#             SEACells (Harmony)  0.070929  0.567  0.731             0.236
#             SEACells (PCA)      0.089088  0.766  0.955             0.231
#             scProto             0.241559  0.400  0.890             0.492
#
#                                f1_range
#
# dataset     method
# lung        Leiden (ComBat)       0.718
#             Leiden (Harmony)      0.532
#             SEACells (ComBat)     0.356
#             SEACells (Harmony)    0.576
#             SEACells (PCA)        0.131
#             scProto               0.971
# pancreas    Leiden (ComBat)       0.800
#             Leiden (Harmony)      0.455
#             SEACells (ComBat)     0.857
#             SEACells (Harmony)    0.494
#             SEACells (PCA)        0.833
#             scProto               0.815
# pbmc-immune Leiden (ComBat)       0.656
#             Leiden (Harmony)      0.386
#             SEACells (ComBat)     0.118
#             SEACells (Harmony)    0.164
#             SEACells (PCA)        0.189
#             scProto               0.490
