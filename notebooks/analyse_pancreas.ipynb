# %%
import scanpy as sc
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
home = '/ictstr01/home/icb/fatemehs.hashemig/'

# %%
hmgu_adata = sc.read_h5ad(f'{home}/data/scpoli/pancreas_sparse-pca.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 15512 × 4000
#     obs: 'study', 'cell_type', 'n_genes', 'batch'
#     var: 'n_cells'
#     uns: 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'

# %%
adata.X.min(), adata.X.max(), adata.X.mean()
# Out:
# (0.0, 8.758501, 0.13998702)

# %% [markdown]
# # what if I download dataset again, then find hvg then these vals?

# %%
ls /ictstr01/home/icb/fatemehs.hashemig/data
# Out:
# all_cell_markers.txt               panglao.tsv  spatial/
# cell_marker/                       retfound/    vcc_data/
# hlca/                              scivias/     vcc_data.zip
# MNIST/                             scpoli/
# PanglaoDB_markers_27_Mar_2020.tsv  seacell/

# %%
# !wget --user-agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/117.0" \
     --content-disposition \
     https://figshare.com/ndownloader/files/24539828 -O /ictstr01/home/icb/fatemehs.hashemig/data/pancreas.h5ad
# Out:
# --2025-09-04 15:00:49--  https://figshare.com/ndownloader/files/24539828
# Resolving figshare.com (figshare.com)... 99.80.51.214, 52.19.226.89, 54.171.30.128, ...
# Connecting to figshare.com (figshare.com)|99.80.51.214|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/24539828/human_pancreas_norm_complexBatch.h5ad?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20250904/eu-west-1/s3/aws4_request&X-Amz-Date=20250904T130050Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=cccc7b90a22271b6ae6892728d623dfdee6e839ea2088fd08c8e3f8aad2579cb [following]
# ...

# %%
adata = sc.read_h5ad('/ictstr01/home/icb/fatemehs.hashemig/data/pancreas.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 16382 × 19093
#     obs: 'tech', 'celltype', 'size_factors'
#     layers: 'counts'

# %%
adata.X.max()
# Out:
# 13.002677

# %%
sc.pp.highly_variable_genes(adata, n_top_genes=4000)

# %%
def get_hvg(adata):
    return  adata.var[adata.var['highly_variable']].index.tolist()

# %%
hvg_list = get_hvg(adata)

# %%
hmgu_hvg = hmgu_adata.var.index.tolist()

# %%
len(set(hmgu_hvg).intersection(set(hvg_list)))
# Out:
# 1977

# %%
adata_hvg = adata[:, adata.var['highly_variable']].copy()

adata_hvg.X.max()
# Out:
# 13.002677

# %%
hmgu_adata.X.max()
# Out:
# 8.758501

# %%
adata_hvg.write('/ictstr01/home/icb/fatemehs.hashemig/data/pancreas_hvg.h5ad')

# %%
sc.pp.highly_variable_genes(adata, n_top_genes=4000)
hvg_list_v2 = get_hvg(adata)

# %%
len(set(hvg_list_v2).intersection(set(hvg_list)))
# Out:
# 4000

# %% [markdown]
# # do same for immune dataset

# %%
hmgu = sc.read_h5ad(f'{home}/data/scpoli/Immune_ALL_human_hvg.h5ad')

# %%
hmgu
# Out:
# AnnData object with n_obs × n_vars = 33506 × 4000
#     obs: 'batch', 'chemistry', 'data_type', 'dpt_pseudotime', 'final_annotation', 'mt_frac', 'n_counts', 'n_genes', 'sample_ID', 'size_factors', 'species', 'study', 'tissue'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg'
#     layers: 'counts'

# %%
hmgu_hvg = hmgu.var.index.to_list()
hmgu_hvg
# Out:
# ['LINC00115',
#  'KLHL17',
#  'HES4',
#  'ISG15',
#  'B3GALT6',
#  'PUSL1',
#  'TMEM52',
#  'PRKCZ',
#  'PEX10',
#  'PANK4',
#  'FAM213B',
#  'TPRG1L',
#  'DFFB',
#  'AJAP1',
#  'RNF207',
#  'ICMT',
#  'ACOT7',
#  'THAP3',
#  'UTS2',
#  'SLC45A1',
#  'SLC2A5',
#  'SLC25A33',
#  'RBP7',
#  'PGD',
#  'MTOR',
#  'FBXO6',
#  'AGTRAP',
#  'CLCN6',
#  'PLOD1',
#  'TNFRSF8',
#  'DHRS3',
#  'CASP9',
#  'EPHA2',
#  'ARHGEF19',
#  'FBXO42',
#  'NBPF1',
#  'PADI4',
#  'ALDH4A1',
#  'AKR7A3',
#  'PQLC2',
#  'TMCO4',
#  'MUL1',
#  'CDA',
#  'PINK1',
#  'C1QA',
#  'C1QC',
#  'C1QB',
#  'KDM1A',
#  'ZNF436',
#  'TCEA3',
#  'ASAP3',
#  'GALE',
#  'HMGCL',
#  'FUCA1',
#  'CNR2',
#  'CLIC4',
#  'PAQR7',
#  'STMN1',
#  'PAFAH2',
#  'PDIK1L',
#  'ZNF593',
#  'CEP85',
#  'UBXN11',
#  'PIGV',
#  'GPN2',
#  'GPATCH3',
#  'TRNP1',
#  'FGR',
#  'IFI6',
#  'PPP1R8',
#  'RPA2',
#  'SMPDL3B',
#  'XKR8',
#  'PTAFR',
#  'SESN2',
#  'SNHG12',
#  'TAF12',
#  'GMEB1',
#  'MECR',
#  'SNRNP40',
#  'ZCCHC17',
# ...

# %%
# !wget --user-agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/117.0" \
     --content-disposition \
     https://figshare.com/ndownloader/files/25717328 -O /ictstr01/home/icb/fatemehs.hashemig/data/immune.h5ad
# Out:
# --2025-09-04 15:14:07--  https://figshare.com/ndownloader/files/25717328
# Resolving figshare.com (figshare.com)... 54.171.30.128, 52.19.226.89, 99.80.51.214, ...
# Connecting to figshare.com (figshare.com)|54.171.30.128|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/25717328/Immune_ALL_human.h5ad?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20250904/eu-west-1/s3/aws4_request&X-Amz-Date=20250904T131408Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=3349aedd480aaea0e9ed29cba35668651fe20aef7f57fbf8706397adac4415d1 [following]
# ...

# %%
adata = sc.read_h5ad('/ictstr01/home/icb/fatemehs.hashemig/data/immune.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 33506 × 12303
#     obs: 'batch', 'chemistry', 'data_type', 'dpt_pseudotime', 'final_annotation', 'mt_frac', 'n_counts', 'n_genes', 'sample_ID', 'size_factors', 'species', 'study', 'tissue'
#     layers: 'counts'

# %%
sc.pp.highly_variable_genes(adata, n_top_genes=4000)

# %%
hvg = get_hvg(adata)

# %%
len(set(hvg).intersection(set(hmgu_hvg)))
# Out:
# 4000

# %%
adata[:, adata.var['highly_variable']].X.max(), hmgu.X.max()
# Out:
# (11.210063, 11.210063)
