# %%
import os
os.chdir('/ictstr01/home/icb/fatemehs.hashemig/codes/interpretable-ssl')

# %%
from interpretable_ssl.evaluation.metric_helpers.metacell_metrics import *

# %% [markdown]
# # compute seacells for immune ds

# %%
import scanpy as sc
home = '/ictstr01/home/icb/fatemehs.hashemig/'
adata = sc.read_h5ad(f'{home}/data/scpoli/Immune_ALL_human_hvg.h5ad')

# %%
sc.tl.pca(adata)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 33506 × 4000
#     obs: 'batch', 'chemistry', 'data_type', 'dpt_pseudotime', 'final_annotation', 'mt_frac', 'n_counts', 'n_genes', 'sample_ID', 'size_factors', 'species', 'study', 'tissue'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg', 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     layers: 'counts'

# %%
ad, SEACell_ad, model = compute_seacells(adata, 300)
# Out:
# Welcome to SEACells!
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Making graph symmetric...
# Parameter graph_construction = union being used to build KNN graph...
# Computing RBF kernel...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/33506 [00:00<?, ?it/s]
# Constructing CSR matrix...
# Building kernel on X_pca
# Computing diffusion components from X_pca for waypoint initialization ...
# Done.
# Sampling waypoints ...
# Done.
# Selecting 279 cells from waypoint initialization.
# Initializing residual matrix using greedy column selection
# Initializing f and g...
#   0%|          | 0/31 [00:00<?, ?it/s]
#  13%|█▎        | 4/31 [00:00<00:00, 30.60it/s]
#  26%|██▌       | 8/31 [00:00<00:00, 28.19it/s]
#  35%|███▌      | 11/31 [00:00<00:00, 28.02it/s]
#  45%|████▌     | 14/31 [00:00<00:00, 27.69it/s]
#  55%|█████▍    | 17/31 [00:00<00:00, 26.65it/s]
#  65%|██████▍   | 20/31 [00:00<00:00, 26.50it/s]
#  74%|███████▍  | 23/31 [00:00<00:00, 26.21it/s]
#  84%|████████▍ | 26/31 [00:00<00:00, 26.06it/s]
# 100%|██████████| 31/31 [00:01<00:00, 26.48it/s]
# Selecting 21 cells from greedy initialization.
# Randomly initialized A matrix.
# Setting convergence threshold at 0.00339
# Starting iteration 1.
# Completed iteration 1.
# Starting iteration 10.
# Completed iteration 10.
# Starting iteration 20.
# Completed iteration 20.
# Converged after 27 iterations.
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 1/300 [00:00<00:33,  8.92it/s]
#   9%|▉         | 28/300 [00:00<00:01, 153.49it/s]
#  19%|█▊        | 56/300 [00:00<00:01, 206.14it/s]
#  28%|██▊       | 84/300 [00:00<00:00, 232.55it/s]
#  37%|███▋      | 112/300 [00:00<00:00, 247.06it/s]
#  47%|████▋     | 140/300 [00:00<00:00, 255.47it/s]
#  56%|█████▌    | 167/300 [00:00<00:00, 259.94it/s]
#  65%|██████▌   | 195/300 [00:00<00:00, 263.56it/s]
#  74%|███████▍  | 222/300 [00:00<00:00, 265.26it/s]
#  83%|████████▎ | 249/300 [00:01<00:00, 264.54it/s]
# 100%|██████████| 300/300 [00:01<00:00, 245.90it/s]
# /home/icb/fatemehs.hashemig/miniconda3/envs/shiny-apex/lib/python3.12/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(

# %%
SEACell_ad.write(f'{home}/models/pbmc-immune/seacell_agg.h5ad')
ad.write(f'{home}/models/pbmc-immune/seacell_sc.h5ad')

# %% [markdown]
# # compute pancreas 1 ds seacells

# %%
adata = sc.read_h5ad(f'{home}/data/pancreas_hvg.h5ad')

# %%
adata = adata[adata.obs.tech == 'inDrop3'].copy()

# %%
sc.tl.pca(adata)

# %%
ad, SEACell_ad, model = compute_seacells(adata, 50)
# Out:
# Welcome to SEACells!
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/3605 [00:00<?, ?it/s]
# Making graph symmetric...
# Parameter graph_construction = union being used to build KNN graph...
# Computing RBF kernel...
#   0%|          | 0/3605 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/3605 [00:00<?, ?it/s]
# Constructing CSR matrix...
# Building kernel on X_pca
# Computing diffusion components from X_pca for waypoint initialization ...
# Done.
# Sampling waypoints ...
# Done.
# Selecting 45 cells from waypoint initialization.
# Initializing residual matrix using greedy column selection
# Initializing f and g...
# 100%|██████████| 15/15 [00:00<00:00, 478.40it/s]
# Selecting 5 cells from greedy initialization.
# Randomly initialized A matrix.
# Setting convergence threshold at 0.00109
# Starting iteration 1.
# Completed iteration 1.
# Starting iteration 10.
# Completed iteration 10.
# Starting iteration 20.
# Completed iteration 20.
# Converged after 29 iterations.
# 100%|██████████| 50/50 [00:00<00:00, 600.58it/s]
# /home/icb/fatemehs.hashemig/miniconda3/envs/shiny-apex/lib/python3.12/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(

# %%
SEACell_ad.write(f'{home}/models/pancreas/inDrop3_seacells.h5ad')

# %% [markdown]
# ## save seacell metacell metrics

# %%
metrics = get_metacell_metrics(adata, 'celltype')

# %%
save_seacell_df(metrics, f'{home}/models/pancreas/inDrop3-seacell/')

# %% [markdown]
# # try harmoney + seacell [for pancreas]
